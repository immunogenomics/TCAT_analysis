# %%
# %matplotlib inline

from FlowCytometryTools import FCMeasurement

# %%
sample = FCMeasurement(ID='Test Sample', datafile='../../../Data/PerDataset/Stimseq/Sorts/CEFX_10X_2_2023.05.12/051223_Stim.fcs')

# %%
print(sample.channels)
# Out:
#                     $PnN    $PnR  $PnB    $PnE  $PnV  $PnG       $PnS
# Channel Number
# 1                  FSC-A  262144    32  [0, 0]   140   1.0      FSC-A
# 2                  FSC-H  262144    32  [0, 0]   140   1.0      FSC-H
# 3                  FSC-W  262144    32  [0, 0]   140   1.0      FSC-W
# 4                  SSC-A  262144    32  [0, 0]   340   1.0      SSC-A
# 5                  SSC-H  262144    32  [0, 0]   340   1.0      SSC-H
# 6                  SSC-W  262144    32  [0, 0]   340   1.0      SSC-W
# 7                 FITC-A  262144    32  [0, 0]   530   1.0        CD4
# 8                   PE-A  262144    32  [0, 0]   550   1.0       OX40
# 9                BV421-A  262144    32  [0, 0]   470   1.0        CD3
# 10              AmCyan-A  262144    32  [0, 0]   490   1.0  LIVE DEAD
# 11               BV786-A  262144    32  [0, 0]   590   1.0       PDL1
# 12                 APC-A  262144    32  [0, 0]   600   1.0      CD137
# ...

# %%
raw_data = sample.data
raw_data.head()
# Out:
#           FSC-A    FSC-H         FSC-W         SSC-A    SSC-H         SSC-W  \
# 0  54481.761719  44513.0  80212.898438  55388.539062  46226.0  78526.007812
# 1  78782.617188  58755.0  87875.039062  74205.898438  55250.0  88020.960938
# 2  65057.101562  51014.0  83576.718750  57882.980469  46999.0  80712.765625
# 3  69358.718750  53115.0  85578.343750  79533.437500  61553.0  84679.929688
# 4  69079.742188  52822.0  85706.906250  90725.617188  70743.0  84047.804688
#
#            CD4      OX40           CD3    LIVE DEAD         PDL1        CD137  \
# 0   143.500000     51.00  18084.390625  1436.400024    45.599998   204.119995
# 1  3469.419922  30088.50   7630.020020   870.959961   570.000000  4338.810059
# 2  7667.819824    777.00  12325.679688  1251.719971   205.199997    64.260002
# 3  7050.359863   2752.50  32635.349609  2647.649902  1442.669922   100.800003
# 4   200.080002    258.75  18356.279297  1493.400024   233.699997    32.759998
#
#         Time
# 0  21.700001
# ...
