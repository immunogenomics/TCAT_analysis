# %%
library(Seurat)
# Out:
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject

# %%
seurat_object <- readRDS("../../../Data/PerDataset/Sparks2023/GSE206265_covid_flu.CITEseq.Seurat.obj.RDS")

# %%
names(seurat_object@meta.data)
# Out:
#  [1] "alt.subject.id"
#  [2] "visit"
#  [3] "covid.diagnosis.start.date.to.sample.drawn"
#  [4] "group"
#  [5] "sex"
#  [6] "age"
#  [7] "race"
#  [8] "ethnicity"
#  [9] "flu.vax.count.10yr"
# [10] "vaccine"
# [11] "vaccine.side.effects"
# [12] "long.covid.symptoms"
# [13] "Batch"
# [14] "nCount_RNA"
# [15] "nCount_HTO"
# [16] "nCount_CITE"
# [17] "nCount_RNA_largest.gene"
# [18] "nCount_SCT"
# [19] "nFeature_RNA"
# [20] "nFeature_HTO"
# [21] "nFeature_CITE"
# [22] "nFeature_SCT"
# [23] "percent.mt"
# [24] "percent.largest.gene"
# [25] "coarse.cell.type"
# [26] "cell.type"

# %%
FeaturePlot(seurat_object, features = 'nFeature_CITE')
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
seurat_object
# Out:
# An object of class Seurat
# 52112 features across 632100 samples within 4 assays
# Active assay: CITE (138 features, 0 variable features)
#  3 layers present: counts, data, scale.data
#  3 other assays present: RNA, HTO, SCT
#  1 dimensional reduction calculated: adt.umap

# %%
umap_data <- seurat_object[["adt.umap"]]@cell.embeddings

# %%
write.table(umap_data, file = "../../../Data/PerDataset/Sparks2023/GSE206265_covid_flu.CITEseq.Seurat.UMAP.tsv", sep = "\t", row.names = TRUE, quote = FALSE)
