# %%
library(Seurat)
library(tidyverse)
library(scalop)
# Out:
# Attaching SeuratObject
#
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# Warning message:
# “package ‘tidyr’ was built under R version 4.1.2”
# Warning message:
# “package ‘readr’ was built under R version 4.1.2”
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
#
#
#
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# Registered S3 method overwritten by 'ggtree':
#   method      from
#   identify.gg ggfun
#
# Warning message:
# “replacing previous import ‘AnnotationDbi::select’ by ‘dplyr::select’ when loading ‘scalop’”

# %% [markdown]
# ## Run using sample data

# %%
MinGenes = 25

# %%
MP_list = readRDS('../../../Data/Misc/Gavish_2023_Nat/MP_list.RDS')

# %%
MP_list %>% str
# Out:
# List of 8
#  $ Cancer     :List of 41
#   ..$ MP1  Cell Cycle - G2/M       : chr [1:50] "TOP2A" "UBE2C" "HMGB2" "NUSAP1" ...
#   ..$ MP2  Cell Cycle - G1/S       : chr [1:50] "PCNA" "RRM2" "FEN1" "GINS2" ...
#   ..$ MP3  Cell Cylce HMG-rich     : chr [1:50] "STMN1" "TUBA1B" "H2AFZ" "DUT" ...
#   ..$ MP4  Chromatin               : chr [1:50] "MT-ND6" "DST" "SMARCA5" "SPEN" ...
#   ..$ MP5 Stress                   : chr [1:50] "ATF3" "EGR1" "FOS" "PPP1R15A" ...
#   ..$ MP6 Hypoxia                  : chr [1:50] "NDRG1" "BNIP3" "SLC2A1" "P4HA1" ...
#   ..$ MP7 Stress (in vitro)        : chr [1:50] "DDIT3" "SLC3A2" "TRIB3" "ASNS" ...
#   ..$ MP8 Proteasomal degradation  : chr [1:50] "PSMA3" "PSMC4" "MDH1" "PRDX1" ...
#   ..$ MP9 Unfolded protein response: chr [1:50] "PDIA3" "MANF" "PDIA4" "CRELD2" ...
#   ..$ MP10 Protein maturation      : chr [1:50] "RPN2" "PDIA3" "ATP6AP2" "HSPA5" ...
#   ..$ MP11 Translation initiation  : chr [1:50] "EPB41L4A-AS1" "IMPDH2" "AHCY" "NOB1" ...
#   ..$ MP12 EMT-I                   : chr [1:50] "COL1A2" "SPARC" "COL1A1" "COL3A1" ...
#   ..$ MP13 EMT-II                  : chr [1:50] "LAMC2" "LAMB3" "LAMA3" "EMP3" ...
#   ..$ MP14 EMT-III                 : chr [1:50] "ANXA2" "KRT19" "S100A6" "TNFRSF12A" ...
#   ..$ MP15 EMT IV                  : chr [1:50] "KRT15" "CXCL14" "ALDH3A1" "DAPL1" ...
#   ..$ MP16 MES (glioma)            : chr [1:50] "EMP1" "GAP43" "TNFRSF12A" "CD44" ...
#   ..$ MP17 Interferon/MHC-II (I)   : chr [1:50] "ISG15" "CD74" "IFI6" "HLA-DRA" ...
#   ..$ MP18 Interferon/MHC-II (II)  : chr [1:50] "CD74" "HLA-DRA" "HLA-DRB1" "ALDH1A1" ...
#   ..$ MP19 Epithelial Senescence   : chr [1:50] "SLPI" "S100A9" "LCN2" "S100A8" ...
#   ..$ MP20 MYC                     : chr [1:50] "NME1" "C1QBP" "FABP5" "SRM" ...
#   ..$ MP21 Respiration             : chr [1:50] "SLIRP" "ROMO1" "ATP5I" "COX7B" ...
#   ..$ MP22 Secreted I              : chr [1:50] "CXCL8" "PHLDA1" "MAFF" "KDM6B" ...
#   ..$ MP23 Secreted II             : chr [1:50] "LCN2" "CP" "WFDC2" "AGR2" ...
#   ..$ MP24 Cilia                   : chr [1:50] "C9ORF116" "CAPS" "RSPH1" "TPPP3" ...
#   ..$ MP25 Astrocytes              : chr [1:50] "SPARCL1" "GFAP" "CLU" "CRYAB" ...
#   ..$ MP26 NPC Glioma              : chr [1:50] "STMN2" "DCX" "STMN4" "TAGLN3" ...
#   ..$ MP27 Oligo Progenitor        : chr [1:50] "SIRT2" "GPR17" "OLIG1" "APOD" ...
#   ..$ MP28 Oligo normal            : chr [1:50] "APOD" "MBP" "PLA2G16" "PLP1" ...
#   ..$ MP29 NPC/OPC                 : chr [1:50] "BTG2" "SOX6" "BAZ2B" "SOX4" ...
#   ..$ MP30 PDAC-classical          : chr [1:50] "TFF1" "TFF3" "CEACAM6" "AGR2" ...
#   ..$ MP31 Alveolar                : chr [1:50] "SFTPA1" "SFTPA2" "SFTPD" "LRRK2" ...
#   ..$ MP32 Skin-pigmentation       : chr [1:50] "PHACTR1" "TBC1D7" "MLANA" "ASAH1" ...
#   ..$ MP33 RBCs                    : chr [1:50] "BLVRB" "HBB" "APOC1" "CA1" ...
#   ..$ MP34 Platelet-activation     : chr [1:50] "RGS18" "PDLIM1" "ITGA2B" "PLEK" ...
#   ..$ MP35 Hemato-related-I        : chr [1:50] "CSF3R" "SPINK2" "VAMP5" "AZU1" ...
#   ..$ MP36 IG                      : chr [1:50] "IGLC2" "IGLC3" "IGHA2" "IGHA1" ...
#   ..$ MP37 Hemato-related-II       : chr [1:50] "CTNNBL1" "FCER1A" "GATA2" "CD84" ...
#   ..$ MP38 Glutathione             : chr [1:50] "NAT8" "ACSM2B" "LGALS2" "AMN" ...
#   ..$ MP39 Metal-response          : chr [1:50] "MT1X" "CAV1" "MT1E" "C5ORF46" ...
#   ..$ MP40 PDAC-related            : chr [1:50] "ISG20" "KLK10" "CEACAM1" "F3" ...
#   ..$ MP41 Unassigned              : chr [1:50] "DST" "KMT2A" "MALAT1" "MIR6515" ...
#  $ Endothelial:List of 15
#   ..$ MP1 Notch-signaling: chr [1:50] "IGFBP3" "SEMA3G" "EFNB2" "ARL15" ...
#   ..$ MP2 MHC-II/Secreted: chr [1:50] "ACKR1" "CLU" "SELP" "ADIRF" ...
#   ..$ MP3 Endo1          : chr [1:50] "INSR" "RGCC" "COL4A1" "FLT1" ...
#   ..$ MP4 Stress         : chr [1:50] "EGR1" "SOCS3" "CDKN1A" "FOSB" ...
#   ..$ MP5 Endo2          : chr [1:50] "TFF3" "CCL21" "MMRN1" "FABP4" ...
#   ..$ MP6 Cell-cycle     : chr [1:50] "HMGB2" "CKS1B" "STMN1" "HIST1H4C" ...
#   ..$ MP7 Endo3          : chr [1:50] "VWF" "RGCC" "RNASE1" "CLDN5" ...
#   ..$ MP8 Endo4          : chr [1:50] "CRHBP" "EMCN" "FCN3" "IGFBP5" ...
#   ..$ MP9 Endo5          : chr [1:50] "PGF" "CTHRC1" "PXDN" "IL32" ...
#   ..$ MP10 Interferon    : chr [1:50] "GBP1" "GBP4" "IFIT3" "IFIT1" ...
#   ..$ MP11 Endo6         : chr [1:50] "IGFBP5" "APLNR" "NR2F2" "SLCO2A1" ...
#   ..$ MP12 Endo7         : chr [1:50] "HPGD" "S100A4" "CA4" "EDNRB" ...
#   ..$ MP13 Endo8         : chr [1:50] "RGCC" "ID2" "SGK1" "TM4SF18" ...
#   ..$ MP14 NF-kb         : chr [1:50] "SELE" "ACKR1" "SOD2" "AKAP12" ...
#   ..$ MP15 Coagulation   : chr [1:50] "FN1" "PMP22" "TFPI" "DNASE1L3" ...
#  $ Epithelial :List of 24
#   ..$ MP1 Stress             : chr [1:50] "EGR1" "FOS" "JUN" "ATF3" ...
#   ..$ MP2 Secreted           : chr [1:50] "SLPI" "WFDC2" "LCN2" "SCGB3A1" ...
#   ..$ MP3 Alveolar           : chr [1:50] "NAPSA" "SFTPA1" "SFTPA2" "SFTPB" ...
#   ..$ MP4 Cilia              : chr [1:50] "TPPP3" "CAPS" "CETN2" "PIFO" ...
#   ..$ MP5 Cell-cycle         : chr [1:50] "HMGB2" "STMN1" "UBE2C" "CKS2" ...
#   ..$ MP6 EpiSen             : chr [1:50] "S100A8" "S100A9" "KRT6A" "FABP5" ...
#   ..$ MP7 V-ATPase           : chr [1:50] "TMEM213" "ATP6AP2" "LGALS3" "ATP6V1B1" ...
#   ..$ MP8 Metabolism-Kidney1 : chr [1:50] "GLYAT" "UGT2B7" "NAT8" "DAB2" ...
#   ..$ MP9 Epi1               : chr [1:50] "AGER" "CAV1" "EMP2" "CAV2" ...
#   ..$ MP10 Interferon/MHC    : chr [1:50] "IFI27" "IFITM3" "CD74" "GNG11" ...
#   ..$ MP11 EMT-like1         : chr [1:50] "DST" "KRT15" "KRT17" "CAV1" ...
#   ..$ MP12 Respiration       : chr [1:50] "DEFB1" "CKB" "MPC1" "CHCHD10" ...
#   ..$ MP13 PDAC-related1     : chr [1:50] "FXYD2" "OLFM4" "PIGR" "SERPINA1" ...
#   ..$ MP14 PDAC-related2     : chr [1:50] "C15ORF48" "CEACAM5" "DUOX2" "CEACAM6" ...
#   ..$ MP15 Epi2              : chr [1:50] "WFDC2" "ADIRF" "S100A2" "SLPI" ...
#   ..$ MP16 Metabolism-Kidney2: chr [1:50] "AQP2" "HSD11B2" "RALBP1" "AQP3" ...
#   ..$ MP17 EMT-like2         : chr [1:50] "IL32" "MMP7" "VIM" "ANXA1" ...
#   ..$ MP18 Colon-related     : chr [1:50] "TFF3" "FCGBP" "REG4" "ZG16" ...
#   ..$ MP19 Neuroendocrine    : chr [1:50] "INS" "PCSK1N" "TTR" "FXYD2" ...
#   ..$ MP20 MYC               : chr [1:50] "FABP5" "MRPL12" "NME1" "SRM" ...
#   ..$ MP21 Androgen-prostate : chr [1:50] "LRRC26" "NKX3-1" "RDH11" "TMPRSS2" ...
#   ..$ MP22 Epi3              : chr [1:50] "HBEGF" "ODC1" "AREG" "KRT16" ...
#   ..$ MP23 PDAC-related3     : chr [1:50] "ALDOB" "PIGR" "ANPEP" "C19ORF77" ...
#   ..$ MP24 Epi4              : chr [1:50] "CD9" "EPCAM" "HSP90B1" "SPINT2" ...
#  $ Fibroblasts:List of 22
#   ..$ MP1 CAF1             : chr [1:50] "CTHRC1" "POSTN" "COL1A1" "SFRP2" ...
#   ..$ MP2 Pericyte-like    : chr [1:50] "NDUFA4L2" "RGS5" "ACTA2" "ADIRF" ...
#   ..$ MP3 Complement       : chr [1:50] "CFD" "C3" "APOD" "PTGDS" ...
#   ..$ MP4 Stress           : chr [1:50] "ATF3" "FOSB" "ZFP36" "BTG2" ...
#   ..$ MP5 Hypoxia          : chr [1:50] "ADM" "MT2A" "DDIT4" "IER3" ...
#   ..$ MP6 Cell-cycle       : chr [1:50] "HMGB2" "PTTG1" "STMN1" "BIRC5" ...
#   ..$ MP7 Interferon       : chr [1:50] "ISG15" "IFIT3" "LAP3" "IFI44L" ...
#   ..$ MP8 Myofibroblasts   : chr [1:50] "TAGLN" "CSRP1" "ACTA2" "KDELR3" ...
#   ..$ MP9 PI16+            : chr [1:50] "PI16" "SEMA3C" "CD55" "IGFBP5" ...
#   ..$ MP10 Metal-response  : chr [1:50] "PRG4" "PLA2G2A" "CHI3L1" "HP" ...
#   ..$ MP11 CAF2            : chr [1:50] "COL18A1" "F2R" "SPON2" "TNFRSF21" ...
#   ..$ MP12 CAF3            : chr [1:50] "PTGDS" "GPC3" "CES1" "A2M" ...
#   ..$ MP13 MHC-II/Cytokine : chr [1:50] "CCL19" "PTGDS" "CD74" "TNFSF13B" ...
#   ..$ MP14 CAF4            : chr [1:50] "DST" "NKTR" "MACF1" "NEAT1" ...
#   ..$ MP15 Lipid-metabolism: chr [1:50] "THY1" "CD36" "FABP5" "MARCKSL1" ...
#   ..$ MP16 CAF5            : chr [1:50] "FXYD1" "MT1E" "MT1M" "NTRK2" ...
#   ..$ MP17 CAF6            : chr [1:50] "HAS1" "CRIP2" "TM4SF1" "YWHAH" ...
#   ..$ MP18 CAF7            : chr [1:50] "MASP1" "CRABP1" "CXCL1" "IGFBP2" ...
#   ..$ MP19 CAF8            : chr [1:50] "MEST" "ANO1" "CXCL14" "SLC6A6" ...
#   ..$ MP20 MHC-II          : chr [1:50] "CRYAB" "HLA-DRA" "HLA-DRB1" "CLU" ...
#   ..$ MP21 CAF9            : chr [1:50] "DDX21" "INHBA" "THBS1" "C11ORF96" ...
#   ..$ MP22 CAF10           : chr [1:50] "CXCL14" "F3" "NSG1" "PDGFRA" ...
#  $ Macrophages:List of 13
#   ..$ MP1 Lipid-associated          : chr [1:50] "APOE" "C1QB" "LGMN" "APOC1" ...
#   ..$ MP2 Monocyte/Secreted         : chr [1:50] "IL1B" "CXCL2" "G0S2" "CXCL8" ...
#   ..$ MP3 Cell-cycle                : chr [1:50] "STMN1" "CKS1B" "HMGB2" "TUBB" ...
#   ..$ MP4 Interferon                : chr [1:50] "CXCL10" "ISG15" "GBP1" "IFIT3" ...
#   ..$ MP5 MES/Glycolysis            : chr [1:50] "SPP1" "GPNMB" "S100A10" "FABP5" ...
#   ..$ MP6 MAC1                      : chr [1:50] "FCN1" "CD52" "FCGR3A" "IFITM2" ...
#   ..$ MP7 Stress/HSP                : chr [1:50] "JUN" "DNAJB1" "HSPA1B" "HSPA1A" ...
#   ..$ MP8 MAC2                      : chr [1:50] "FABP4" "MARCO" "RBP4" "PCOLCE2" ...
#   ..$ MP9 Proteasomal-degradation   : chr [1:50] "NME1" "FABP5" "HSPA5" "CCT5" ...
#   ..$ MP10 MAC3                     : chr [1:50] "C3" "OLFML3" "C1QC" "C1QB" ...
#   ..$ MP11 MYC/Mitochondria         : chr [1:50] "NME1" "NHP2" "C1QBP" "PHB" ...
#   ..$ MP12 Unfolded-protein-response: chr [1:50] "HSPA5" "MANF" "HSP90B1" "SDF2L1" ...
#   ..$ MP13 Respiration              : chr [1:50] "ISG15" "CCL2" "COX7B" "NDUFB2" ...
#  $ CD4_T_cells:List of 10
#   ..$ MP1 T_reg         : chr [1:50] "IL2RA" "TNFRSF18" "TNFRSF4" "TIGIT" ...
#   ..$ MP2 Naive1        : chr [1:50] "ANXA1" "FOS" "CD69" "CCR7" ...
#   ..$ MP3 Cell_cycle    : chr [1:50] "STMN1" "TUBA1B" "TUBB" "NUSAP1" ...
#   ..$ MP4 Cytotoxic     : chr [1:50] "CCL5" "GZMA" "CCL4" "ID2" ...
#   ..$ MP5 Dysfunction   : chr [1:50] "NR3C1" "CXCL13" "FKBP5" "ITM2A" ...
#   ..$ MP6 Interferon    : chr [1:50] "ISG15" "IFIT1" "MX1" "RSAD2" ...
#   ..$ MP7 Glycolysis/MYC: chr [1:50] "NME1" "RANBP1" "CCT5" "EIF5A" ...
#   ..$ MP8 Naive2        : chr [1:50] "CCR7" "LEF1" "MAL" "SELL" ...
#   ..$ MP9 Unassigned    : chr [1:50] "ARPC4" "CKLF" "LGALS1" "ALOX5AP" ...
#   ..$ MP10 Stress/HSP   : chr [1:50] "DNAJB1" "FKBP4" "DNAJA4" "HSPA1B" ...
#  $ CD8_T_cells:List of 12
#   ..$ MP1 Cytotoxic     : chr [1:50] "GZMB" "GZMH" "PRF1" "CCL4" ...
#   ..$ MP2 Cell_cycle    : chr [1:50] "STMN1" "TUBB" "TUBA1B" "HMGB2" ...
#   ..$ MP3 Memory/Naive1 : chr [1:50] "FOS" "IL7R" "DUSP1" "GPR183" ...
#   ..$ MP4 Interferon    : chr [1:50] "MX1" "ISG15" "IFI6" "OASL" ...
#   ..$ MP5 Unassigned1   : chr [1:50] "GIMAP7" "GIMAP4" "GZMK" "ATRX" ...
#   ..$ MP6 Naive2        : chr [1:50] "SELL" "TMEM123" "CCR7" "LTB" ...
#   ..$ MP7 Glycolysis/MYC: chr [1:50] "FABP5" "NME1" "C1QBP" "RANBP1" ...
#   ..$ MP8 Chromatin     : chr [1:50] "NEAT1" "SYNE2" "MACF1" "AHNAK" ...
#   ..$ MP9 Unassigned2   : chr [1:50] "COTL1" "PPP1CA" "PSME2" "ARPC1B" ...
#   ..$ MP10 Heat_shock   : chr [1:50] "HSPA1B" "HSPH1" "HSPA1A" "HSPA6" ...
#   ..$ MP11 Naive3       : chr [1:50] "KLRB1" "LTB" "RORA" "IL7R" ...
#   ..$ MP12 Dysfunction  : chr [1:50] "TNFRSF18" "ARID5B" "BATF" "NR3C1" ...
#  $ B_cells    :List of 12
#   ..$ MP1 Plasma        : chr [1:50] "DERL3" "MZB1" "JCHAIN" "PRDX4" ...
#   ..$ MP2 MHC-II        : chr [1:50] "HLA-DPB1" "HLA-DRA" "HLA-DRB1" "LAPTM5" ...
#   ..$ MP3 Cell-cycle    : chr [1:50] "HMGB2" "STMN1" "TUBA1B" "TUBB" ...
#   ..$ MP4 Stress        : chr [1:50] "CD69" "FOS" "JUN" "CD83" ...
#   ..$ MP5 B-cells1      : chr [1:50] "CRIP1" "TNFRSF13B" "CAPG" "ITGB1" ...
#   ..$ MP6 Metabolism/MYC: chr [1:50] "PSME2" "ENO1" "LDHA" "NME1" ...
#   ..$ MP7 B-cells2      : chr [1:50] "LRMP" "NEIL1" "TCL1A" "MARCKSL1" ...
#   ..$ MP8 Interferon    : chr [1:50] "MX1" "PLSCR1" "SAMD9L" "GBP1" ...
#   ..$ MP9 Progenitor    : chr [1:50] "SOX4" "VPREB1" "CD9" "IGLL1" ...
#   ..$ MP10 B-cells3     : chr [1:50] "NKTR" "ARGLU1" "ATM" "RBM6" ...
#   ..$ MP11 Respiration  : chr [1:50] "PPIB" "H2AFZ" "JCHAIN" "ATP5G3" ...
#   ..$ MP12 HSP/Stress   : chr [1:50] "CACYBP" "HSPA1B" "CD69" "DNAJB1" ...

# %%
My_study = readRDS('../../../Data/Misc/Gavish_2023_Nat/My_study.RDS')

# %%
My_study %>% str
# Out:
# List of 5
#  $ Puram_2017_HNSCC_scRNAseq_26:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. ..@ i       : int [1:1616914] 0 1 4 6 7 11 16 19 20 22 ...
#   .. ..@ p       : int [1:285] 0 6965 14320 22064 28034 33490 38976 46014 52783 58126 ...
#   .. ..@ Dim     : int [1:2] 23686 284
#   .. ..@ Dimnames:List of 2
#   .. .. ..$ : chr [1:23686] "C9orf152" "RPS11" "ELMO2" "CREB3L1" ...
#   .. .. ..$ : chr [1:284] "HN26_P14_D11_S239_comb" "HN26_P25_H09_S189_comb" "HN26_P14_H06_S282_comb" "HN26_P25_C09_S129_comb" ...
#   .. ..@ x       : num [1:1616914] 3.45 1553.35 61.29 111.59 0.95 ...
#   .. ..@ factors : list()
#  $ Puram_2017_HNSCC_scRNAseq_25:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. ..@ i       : int [1:1349159] 1 7 11 12 26 39 41 53 60 72 ...
#   .. ..@ p       : int [1:230] 0 3991 11746 18885 25129 31541 38184 46279 53831 61924 ...
#   .. ..@ Dim     : int [1:2] 23686 229
#   .. ..@ Dimnames:List of 2
#   .. .. ..$ : chr [1:23686] "C9orf152" "RPS11" "ELMO2" "CREB3L1" ...
#   .. .. ..$ : chr [1:229] "HN25_P25_C04_S316_comb" "HN25_P24_B02_S110_comb" "HN25_P25_B12_S312_comb" "HN25_P5_E11_S59_comb" ...
#   .. ..@ x       : num [1:1349159] 618.7 9.93 1.33 8.36 3687.74 ...
#   .. ..@ factors : list()
#  $ Puram_2017_HNSCC_scRNAseq_28:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. ..@ i       : int [1:904099] 1 2 12 16 19 20 22 26 30 32 ...
#   .. ..@ p       : int [1:150] 0 6770 11070 16510 23729 29936 36748 43789 51486 57885 ...
#   .. ..@ Dim     : int [1:2] 23686 149
#   .. ..@ Dimnames:List of 2
#   .. .. ..$ : chr [1:23686] "C9orf152" "RPS11" "ELMO2" "CREB3L1" ...
#   .. .. ..$ : chr [1:149] "HN28_P15_B12_S312_comb" "HN28_P6_A11_S107_comb" "HN28_P15_G07_S367_comb" "HN28_P15_F12_S360_comb" ...
#   .. ..@ x       : num [1:904099] 511.97 52.36 1.42 8.14 22.91 ...
#   .. ..@ factors : list()
#  $ Puram_2017_HNSCC_scRNAseq_24:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. ..@ i       : int [1:68708] 1 7 11 12 19 20 22 26 30 32 ...
#   .. ..@ p       : int [1:14] 0 6285 10769 15924 20284 25147 33269 35388 42274 48693 ...
#   .. ..@ Dim     : int [1:2] 23686 13
#   .. ..@ Dimnames:List of 2
#   .. .. ..$ : chr [1:23686] "C9orf152" "RPS11" "ELMO2" "CREB3L1" ...
#   .. .. ..$ : chr [1:13] "HNSCC24_P3_D02_S38_comb" "HNSCC24_P3_A01_S1_comb" "HNSCC24_P3_D01_S37_comb" "HNSCC24_P3_B03_S15_comb" ...
#   .. ..@ x       : num [1:68708] 1096.07 1.29 0.62 12.12 161.39 ...
#   .. ..@ factors : list()
#  $ Puram_2017_HNSCC_scRNAseq_18:Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. ..@ i       : int [1:1145982] 1 7 13 26 30 34 47 65 66 78 ...
#   .. ..@ p       : int [1:264] 0 3956 8800 12056 17447 23106 27586 29681 33865 37542 ...
#   .. ..@ Dim     : int [1:2] 23686 263
#   .. ..@ Dimnames:List of 2
#   .. .. ..$ : chr [1:23686] "C9orf152" "RPS11" "ELMO2" "CREB3L1" ...
#   .. .. ..$ : chr [1:263] "HNSCC18_P4_A12_S12_comb" "HNSCC18_P4_H04_S88_comb" "HNSCC18_P4_G09_S81_comb" "HNSCC18_P4_E01_S49_comb" ...
#   .. ..@ x       : num [1:1145982] 189.33 0.89 1.81 215.98 119.49 ...
#   .. ..@ factors : list()

# %%
My_study[[1]][1:5, 1:5]
# Out:
# 5 x 5 sparse Matrix of class "dgCMatrix"
#          HN26_P14_D11_S239_comb HN26_P25_H09_S189_comb HN26_P14_H06_S282_comb
# C9orf152               3.450036               .                       .
# RPS11               1553.353259            1768.109055             1230.51898
# ELMO2                  .                      4.189955                .
# CREB3L1                .                      .                       .
# PNMA1                 61.290014               1.460023               29.85885
#          HN26_P25_C09_S129_comb HNSCC26_P24_H05_S377_comb
# C9orf152                 .                        .
# RPS11                  935.3653                2460.39855
# ELMO2                    .                       28.94127
# CREB3L1                  .                        .
# PNMA1                  109.7123                   .

# %%
My_study %>% dim

# %%
Assign_MP_per_cell_filtered <- Score_cells(L = My_study , cell_type = "Cancer" , MP_list=MP_list)

# %%
system.time({
    scores = sigScores(My_study[[1]], sigs = MP_list,  conserved.genes = MinGenes/50 )
})

# %% [markdown]
# Error 1: x must be an array of 2 dimensiosn

# %%
system.time({
    scores = sigScores(as.matrix(My_study[[1]]), sigs = MP_list,  conserved.genes = MinGenes/50 )
})

# %% [markdown]
# Error 2: Error in scores - expr.scores: non-numeric argument to binary operator

# %%
MP_list_T = MP_list

names(MP_list_T[['CD4_T_cells']]) = paste0('CD4_', names(MP_list_T[['CD4_T_cells']]))
names(MP_list_T[['CD8_T_cells']]) = paste0('CD8_', names(MP_list_T[['CD8_T_cells']]))

MP_list_T = c(MP_list_T[['CD4_T_cells']], MP_list_T[['CD8_T_cells']])

# %%
MP_list
# Out:
# $Cancer
# $Cancer$`MP1  Cell Cycle - G2/M`
#  [1] "TOP2A"    "UBE2C"    "HMGB2"    "NUSAP1"   "CENPF"    "CCNB1"
#  [7] "TPX2"     "CKS2"     "BIRC5"    "PRC1"     "PTTG1"    "KPNA2"
# [13] "MKI67"    "CDC20"    "CDK1"     "CCNB2"    "CDKN3"    "SMC4"
# [19] "NUF2"     "ARL6IP1"  "CKAP2"    "ASPM"     "PLK1"     "CKS1B"
# [25] "CCNA2"    "AURKA"    "MAD2L1"   "GTSE1"    "HMMR"     "UBE2T"
# [31] "CENPE"    "CENPA"    "KIF20B"   "AURKB"    "CDCA3"    "CDCA8"
# [37] "UBE2S"    "KNSTRN"   "KIF2C"    "PBK"      "TUBA1B"   "DLGAP5"
# [43] "TACC3"    "STMN1"    "DEPDC1"   "ECT2"     "CENPW"    "ZWINT"
# [49] "HIST1H4C" "KIF23"
#
# $Cancer$`MP2  Cell Cycle - G1/S`
#  [1] "PCNA"     "RRM2"     "FEN1"     "GINS2"    "TYMS"     "MCM3"
#  [7] "GMNN"     "HIST1H4C" "CLSPN"    "ATAD2"    "TK1"      "KIAA0101"
# [13] "DUT"      "HELLS"    "MCM7"     "UBE2T"    "MCM4"     "CENPU"
# [19] "DHFR"     "ZWINT"    "ASF1B"    "MCM5"     "DNAJC9"   "RFC4"
# [25] "HMGB2"    "CDC6"     "RRM1"     "ORC6"     "CDK1"     "RAD51AP1"
# [31] "RNASEH2A" "CHAF1A"   "CENPK"    "CDCA5"    "SLBP"     "MCM6"
# [37] "TMEM106C" "CENPM"    "MYBL2"    "E2F1"     "USP1"     "DNMT1"
# [43] "PKMYT1"   "MAD2L1"   "PSMC3IP"  "CDCA4"    "RFC2"     "CDC45"
# [49] "UHRF1"    "MCM2"
#
# $Cancer$`MP3  Cell Cylce HMG-rich`
#  [1] "STMN1"     "TUBA1B"    "H2AFZ"     "DUT"       "TUBB"      "PCNA"
#  [7] "HMGB2"     "KIAA0101"  "HMGB1"     "RANBP1"    "RAN"       "TYMS"
# [13] "H2AFV"     "SLC25A5"   "CKS1B"     "SNRPG"     "COX8A"     "HSPE1"
# [19] "SNRPB"     "ANAPC11"   "SLIRP"     "HMGN1"     "NAA38"     "SNRPD1"
# [25] "SNRPE"     "ATP5G3"    "HIST1H4C"  "HSPD1"     "NME1"      "TK1"
# [31] "HMGN2"     "MIF"       "SNRPF"     "ATP5G1"    "TPI1"      "COX5A"
# [37] "ERH"       "HMGA1"     "HNRNPA2B1" "MCM7"      "NUCB2"     "SIVA1"
# [43] "SRSF7"     "YBX1"      "LSM4"      "ANP32B"    "UQCRQ"     "HSPB11"
# [49] "SUMO2"     "SNRPD3"
#
# $Cancer$`MP4  Chromatin`
#  [1] "MT-ND6"    "DST"       "SMARCA5"   "SPEN"      "PCM1"      "GOLGA4"
#  [7] "GOLGB1"    "KCNQ1OT1"  "PHF3"      "PTPN11"    "TRIM44"    "ZNF638"
# [13] "CEP350"    "GOLIM4"    "HIST1H1E"  "MSH6"      "ROCK2"     "SMC1A"
# [19] "SMCHD1"    "ASH1L"     "ATAD2"     "ATAD5"     "BAZ1B"     "NOP14"
# [25] "RIF1"      "SYNE2"     "TJP1"      "TRIP11"    "ENAH"      "HIST1H1C"
# [31] "HIST2H2AC" "NRD1"      "RANBP2"    "SMC5"      "ARGLU1"    "BDP1"
# [37] "SETD2"     "SLK"       "SPAG9"     "SUZ12"     "AHCTF1"    "CLINT1"
# [43] "FAM208B"   "KMT2A"     "MACF1"     "PAXBP1"    "HIST1H1B"  "UACA"
# [49] "SENP6"     "ZMYM4"
#
# $Cancer$`MP5 Stress`
#  [1] "ATF3"     "EGR1"     "FOS"      "PPP1R15A" "JUN"      "DUSP1"
#  [7] "JUNB"     "FOSB"     "IER2"     "GADD45B"  "BTG2"     "ZFP36"
# [13] "DNAJB1"   "NR4A1"    "SERTAD1"  "DDIT3"    "KLF6"     "NFKBIA"
# [19] "HSPA1A"   "HSPA1B"   "CYR61"    "MAFF"     "NFKBIZ"   "IER3"
# [25] "CCNL1"    "MCL1"     "RHOB"     "SOCS3"    "IRF1"     "CDKN1A"
# [31] "HES1"     "ID2"      "KLF4"     "KLF10"    "CXCL2"    "ID1"
# [37] "TOB1"     "TRIB1"    "HSPH1"    "RASD1"    "SAT1"     "DDIT4"
# [43] "EGR2"     "HERPUD1"  "PLK2"     "DNAJA1"   "HSPA6"    "PMAIP1"
# [49] "CITED2"   "ID3"
#
# $Cancer$`MP6 Hypoxia`
#  [1] "NDRG1"        "BNIP3"        "SLC2A1"       "P4HA1"        "VEGFA"
#  [6] "ENO2"         "ADM"          "HILPDA"       "PGK1"         "BNIP3L"
# [11] "FAM162A"      "PLOD2"        "EGLN3"        "LDHA"         "MT1X"
# [16] "NRN1"         "DDIT4"        "DDIT3"        "ERO1A"        "ANGPTL4"
# [21] "IGFBP3"       "PFKP"         "INSIG2"       "NDUFA4L2"     "PDK1"
# [26] "CA9"          "AKAP12"       "C4ORF3"       "IGFBP5"       "GBE1"
# [31] "LGALS3"       "TMEM45A"      "WSB1"         "GPI"          "S100A10"
# [36] "SLC16A3"      "EPB41L4A-AS1" "ALDOA"        "ANKRD37"      "CAV1"
# [41] "AK4"          "DNAJB9"       "ERRFI1"       "MT2A"         "SLC3A2"
# [46] "VIM"          "ENO1"         "PFKFB3"       "HK2"          "CA12"
#
# $Cancer$`MP7 Stress (in vitro)`
#  [1] "DDIT3"        "SLC3A2"       "TRIB3"        "ASNS"         "HERPUD1"
#  [6] "PPP1R15A"     "EPB41L4A-AS1" "SNHG12"       "GARS"         "GADD45A"
# [11] "MTHFD2"       "XBP1"         "CEBPG"        "TAF1D"        "NUPR1"
# [16] "SARS"         "SNHG8"        "ZFAS1"        "DDIT4"        "PHGDH"
# [21] "SHMT2"        "TXNIP"        "ATF4"         "HSPA5"        "GDF15"
# [26] "CARS"         "MAP1LC3B"     "SQSTM1"       "YARS"         "DNAJB9"
# [31] "PSAT1"        "GADD45B"      "ATF3"         "SNHG15"       "RSRC2"
# [36] "CEBPB"        "ARF4"         "EIF1B"        "OSER1"        "BTG1"
# [41] "SNHG7"        "WARS"         "ZFAND2A"      "C6ORF48"      "STC2"
# [46] "ZNF622"       "HSPA9"        "PDRG1"        "UPP1"         "CCDC174"
#
# $Cancer$`MP8 Proteasomal degradation`
#  [1] "PSMA3"   "PSMC4"   "MDH1"    "PRDX1"   "PSMA4"   "PSMC2"   "EIF4A3"
#  [8] "MRPL13"  "PGK1"    "PSMB3"   "PSME2"   "CCT8"    "ANXA1"   "DCAF13"
# [15] "PRMT1"   "SSBP1"   "PSMB1"   "LAPTM4A" "PSMB6"   "CCT5"    "NDUFS2"
# [22] "PDHA1"   "CCT7"    "CDC123"  "CCNB1"   "PCMT1"   "POLR2G"  "HSPA5"
# [29] "XRCC6"   "NDUFA9"  "DPM1"    "SSB"     "EIF3I"   "MCTS1"   "SLC3A2"
# [36] "ECH1"    "PSMD13"  "TUBB4B"  "SNRPB2"  "DDX39A"  "NQO1"    "EIF4A1"
# [43] "SPCS2"   "IMPDH2"  "RTCB"    "GSTO1"   "PDIA3"   "PRDX2"   "NUP37"
# [50] "ILF2"
#
# $Cancer$`MP9 Unfolded protein response`
#  [1] "PDIA3"      "MANF"       "PDIA4"      "CRELD2"     "HSPA5"
#  [6] "SDF2L1"     "CALR"       "MYDGF"      "TMED9"      "ARF4"
# [11] "DNAJB9"     "SELENOK"    "SELENOS"    "CDK2AP2"    "DNAJC3"
# [16] "DNAJB11"    "ERLEC1"     "FKBP11"     "HYOU1"      "PDIA6"
# [21] "SEC61G"     "HERPUD1"    "HSP90B1"    "HSP90B2P"   "OSTC"
# [26] "CCPG1"      "ISG20"      "KDELR2"     "PLPP5"      "PPIB"
# [31] "RRBP1"      "SLC35B1"    "PRDX4"      "RPN2"       "SRPRB"
# [36] "AC068631.2" "FKBP2"      "HM13"       "LMAN1"      "LMAN2"
# [41] "SEL1L"      "SRPRA"      "AC012181.2" "CKAP4"      "MLEC"
# [46] "SEC63"      "SLC3A2"     "TXNDC15"    "ATF4"       "LAPTM4A"
#
# $Cancer$`MP10 Protein maturation`
#  [1] "RPN2"     "PDIA3"    "ATP6AP2"  "HSPA5"    "PDIA6"    "LGALS3BP"
#  [7] "GRN"      "LAPTM4A"  "HSP90B1"  "LAMP1"    "TMEM59"   "EPCAM"
# [13] "GDF15"    "HLA-C"    "OS9"      "PDIA4"    "APLP2"    "AZGP1"
# [19] "CLU"      "CTSA"     "DDOST"    "HLA-A"    "ITM2B"    "LRPAP1"
# [25] "NEAT1"    "PSAP"     "SIL1"     "SLC3A2"   "TIMP1"    "APMAP"
# [31] "APP"      "CTSL"     "LAMP2"    "LMAN2"    "MAGED2"   "PIGT"
# [37] "PRDX4"    "SERPINE2" "TM9SF2"   "TSPAN1"   "ATP6AP1"  "CFI"
# [43] "EPHX1"    "EPRS"     "GGH"      "HEXB"     "MALAT1"   "PPIB"
# [49] "SPP1"     "SERPINA1"
#
# $Cancer$`MP11 Translation initiation`
#  [1] "EPB41L4A-AS1" "IMPDH2"       "AHCY"         "NOB1"         "OXA1L"
#  [6] "EIF2A"        "IGBP1"        "LETMD1"       "RPL22L1"      "SNHG7"
# [11] "SNHG8"        "ZNF581"       "APEX1"        "C19ORF48"     "EIF3M"
# [16] "HIST3H2A"     "LTA4H"        "MYC"          "SNHG19"       "C11ORF1"
# [21] "C6ORF48"      "CCDC85B"      "CCNG1"        "EIF2S3"       "EIF3D"
# [26] "EIF3F"        "RGS10"        "TKT"          "ABHD14B"      "EIF4B"
# [31] "LYRM4"        "PPP1R14B"     "QARS"         "RSL1D1"       "SLC27A5"
# [36] "SRM"          "NME1"         "NBEAL1"       "EIF3E"        "CCNB1IP1"
# [41] "MRPL10"       "HSD17B11"     "TOP1MT"       "NOA1"         "FBL"
# [46] "MRPL45"       "ZNF277"       "PAICS"        "EXOSC5"       "ZFAS1"
#
# $Cancer$`MP12 EMT-I`
#  [1] "COL1A2"   "SPARC"    "COL1A1"   "COL3A1"   "IGFBP7"   "TAGLN"
#  [7] "C1S"      "FN1"      "MGP"      "TIMP1"    "TIMP3"    "BGN"
# [13] "C1R"      "VIM"      "COL6A2"   "COL4A2"   "COL6A1"   "MMP2"
# [19] "DCN"      "COL4A1"   "FSTL1"    "NNMT"     "TPM1"     "TSC22D3"
# [25] "CCDC80"   "CTGF"     "CXCL12"   "ID3"      "LUM"      "MYL9"
# [31] "PRSS23"   "TGFBI"    "TPM2"     "CAV1"     "CYR61"    "IGFBP5"
# [37] "LGALS1"   "SPARCL1"  "A2M"      "ACTA2"    "CALD1"    "COL6A3"
# [43] "CTSK"     "FBLN1"    "IGFBP4"   "POSTN"    "RARRES2"  "SERPING1"
# [49] "SNAI2"    "TCF4"
#
# $Cancer$`MP13 EMT-II`
#  [1] "LAMC2"     "LAMB3"     "LAMA3"     "EMP3"      "TGFBI"     "TNFRSF12A"
#  [7] "FLNA"      "PLAU"      "PMEPA1"    "CAV1"      "KRT17"     "PRSS23"
# [13] "LGALS1"    "VIM"       "S100A2"    "COL17A1"   "FSTL3"     "CST6"
# [19] "IL32"      "PDLIM7"    "SERPINE1"  "ANXA3"     "IGFBP7"    "DCBLD2"
# [25] "F3"        "MT2A"      "TNC"       "ITGB6"     "KRT7"      "PLAUR"
# [31] "PRKCDBP"   "SERPINE2"  "ITGB1"     "RBP1"      "ITGA3"     "CDKN1A"
# [37] "THBS1"     "FN1"       "MMP7"      "TGM2"      "C15ORF48"  "ITGA6"
# [43] "PTHLH"     "TPM1"      "CDA"       "IGFBP6"    "PDPN"      "RHOD"
# [49] "INHBA"     "ITGAV"
#
# $Cancer$`MP14 EMT-III`
#  [1] "ANXA2"     "KRT19"     "S100A6"    "TNFRSF12A" "KRT7"      "LGALS1"
#  [7] "ANXA1"     "TM4SF1"    "S100A10"   "LGALS3"    "S100A16"   "TAGLN2"
# [13] "LMNA"      "CRIP1"     "EZR"       "KRT18"     "S100A11"   "S100A4"
# [19] "EMP3"      "HSPB1"     "KRT8"      "TUBA1A"    "VIM"       "IL32"
# [25] "KLF6"      "ANXA3"     "SH3BGRL3"  "TMSB4X"    "C19ORF33"  "CKB"
# [31] "CLIC1"     "EMP1"      "IFI27"     "ISG15"     "MDK"       "MMP7"
# [37] "PHLDA2"    "PLP2"      "CLDN4"     "MYADM"     "RHOC"      "S100A14"
# [43] "CD24"      "CRIP2"     "MYL12A"    "RAB11FIP1" "S100P"     "STMN1"
# [49] "FXYD3"     "FLNA"
#
# $Cancer$`MP15 EMT IV`
#  [1] "KRT15"    "CXCL14"   "ALDH3A1"  "DAPL1"    "DST"      "CCL2"
#  [7] "TXNIP"    "C12ORF75" "COL17A1"  "DCN"      "HOPX"     "MOXD1"
# [13] "SDCBP"    "SEPP1"    "THBS2"    "TIMP1"    "ASS1"     "GLUL"
# [19] "NFIB"     "NTRK2"    "SERPINH1" "SOX4"     "ANTXR1"   "C1R"
# [25] "C1S"      "C6ORF48"  "CAV1"     "FTH1"     "IGFBP5"   "NCOA7"
# [31] "NINJ1"    "PNRC1"    "SERPINE2" "SERPINF1" "SLC47A2"  "SNAI2"
# [37] "SOCS3"    "SPARC"    "TSC22D1"  "ASPN"     "LTF"      "SFRP1"
# [43] "TP53AIP1" "CD74"     "EGR1"     "BCAM"     "SESN3"    "IFITM1"
# [49] "HTRA1"    "IFIT3"
#
# $Cancer$`MP16 MES (glioma)`
#  [1] "EMP1"        "GAP43"       "TNFRSF12A"   "CD44"        "TNC"
#  [6] "LYST"        "PLAT"        "WWTR1"       "ANXA2"       "GADD45A"
# [11] "LMNA"        "VMP1"        "IGFBP3"      "SCG2"        "HIVEP3"
# [16] "METTL7B"     "RCAN1"       "ZYX"         "CAMK2D"      "IL1RAP"
# [21] "JAG1"        "NAMPT"       "PGM2L1"      "VIM"         "ACTN1"
# [26] "AKAP12"      "IGF2BP2"     "MIR4435-2HG" "NRP2"        "PDLIM4"
# [31] "ANXA1"       "BCAT1"       "CLIC4"       "CREB5"       "DIRAS3"
# [36] "EGR1"        "ELL2"        "F3"          "FRMD5"       "IGFBP7"
# [41] "LINC00152"   "S100A16"     "VCL"         "SAMD4A"      "ADAMTS9-AS2"
# [46] "SLC4A7"      "GFAP"        "CADPS"       "GNG12"       "KLHL4"
#
# $Cancer$`MP17 Interferon/MHC-II (I)`
#  [1] "ISG15"    "CD74"     "IFI6"     "HLA-DRA"  "HLA-DRB1" "IFIT3"
#  [7] "PSMB9"    "IFI44L"   "RARRES3"  "STAT1"    "HLA-DPA1" "MX1"
# [13] "UBE2L6"   "IFITM3"   "BST2"     "OAS1"     "GBP1"     "IFI27"
# [19] "IFIT1"    "TAP1"     "HLA-B"    "IFITM1"   "HLA-DMA"  "ISG20"
# [25] "TNFSF10"  "IFI35"    "IFI44"    "HLA-DPB1" "HLA-E"    "HLA-C"
# [31] "PARP14"   "WARS"     "HLA-DQB1" "LAP3"     "PSMB8"    "C1S"
# [37] "HLA-DRB5" "PLSCR1"   "TYMP"     "C1R"      "SAA1"     "HLA-F"
# [43] "IFIT2"    "SOD2"     "GBP2"     "HLA-A"    "CXCL10"   "HLA-DQA1"
# [49] "PARP9"    "B2M"
#
# $Cancer$`MP18 Interferon/MHC-II (II)`
#  [1] "CD74"     "HLA-DRA"  "HLA-DRB1" "ALDH1A1"  "HLA-DPA1" "IFITM2"
#  [7] "CD9"      "CLU"      "CRYAB"    "NNMT"     "S100A10"  "TMEM176B"
# [13] "C1R"      "C1S"      "DHRS3"    "GPM6B"    "HLA-DRB5" "IFI6"
# [19] "IFITM3"   "PLP1"     "RARRES2"  "S100B"    "SERPING1" "TMEM176A"
# [25] "ANXA1"    "C3"       "CTNNAL1"  "GFRA3"    "MT2A"     "PDK4"
# [31] "PLAT"     "PMP22"    "SEPP1"    "C10ORF10" "EGFL8"    "GPX3"
# [37] "HLA-DMA"  "MT1X"     "SEMA3B"   "UCHL1"    "MMP7"     "LGALS1"
# [43] "CTSD"     "ARPC1B"   "ISG15"    "WFDC2"    "LGALS3BP" "CALM2"
# [49] "TUBA1A"   "A2M"
#
# $Cancer$`MP19 Epithelial Senescence`
#  [1] "SLPI"     "S100A9"   "LCN2"     "S100A8"   "KRT16"    "C15ORF48"
#  [7] "SPRR1B"   "LY6D"     "S100P"    "KRT6B"    "PI3"      "WFDC2"
# [13] "CEACAM6"  "PDZK1IP1" "S100A7"   "TSPAN1"   "KRT13"    "TACSTD2"
# [19] "PSCA"     "IL1RN"    "LYPD3"    "SAA1"     "SERPINB3" "AQP3"
# [25] "CLDN4"    "CXCL17"   "KRT17"    "CRABP2"   "ELF3"     "KRT6A"
# [31] "MAL2"     "SPRR3"    "IGFBP3"   "PRSS22"   "SPRR2D"   "DSC2"
# [37] "GPRC5A"   "KRT7"     "SPRR2A"   "ANXA1"    "MALL"     "CEACAM5"
# [43] "MUC4"     "SERPINB1" "AGR2"     "CLIC3"    "SERPINB4" "FABP5"
# [49] "SULT2B1"  "CLDN7"
#
# $Cancer$`MP20 MYC`
#  [1] "NME1"     "C1QBP"    "FABP5"    "SRM"      "EBNA1BP2" "HSPE1"
#  [7] "DCTPP1"   "NOP16"    "NHP2"     "MRPL12"   "DKC1"     "HSPD1"
# [13] "RANBP1"   "CCT5"     "DDX21"    "ATP5G1"   "PA2G4"    "GPATCH4"
# [19] "TOMM40"   "GNL3"     "PAICS"    "RAN"      "PPA1"     "RUVBL1"
# [25] "CCT2"     "EIF4EBP1" "MYC"      "LDHB"     "TIMM13"   "ODC1"
# [31] "CYCS"     "EIF5A"    "NIFK"     "NOLC1"    "SNRPD1"   "MRPL3"
# [37] "MRTO4"    "SLIRP"    "LDHA"     "NOP56"    "PHB"      "PNO1"
# [43] "DCAF13"   "ENO1"     "NCL"      "NOP58"    "PRMT1"    "BZW2"
# [49] "CMSS1"    "FKBP4"
#
# $Cancer$`MP21 Respiration`
#  [1] "SLIRP"   "ROMO1"   "ATP5I"   "COX7B"   "PET100"  "ATP5G1"  "OST4"
#  [8] "TMEM258" "NDUFA3"  "NDUFB2"  "RPL21"   "USMG5"   "H3F3A"   "NDUFA1"
# [15] "SNRPD2"  "ATP5E"   "COX6B1"  "NDUFS5"  "NME1"    "ATP5J2"  "NDUFB1"
# [22] "NOP10"   "ATOX1"   "PSMB3"   "UQCR10"  "NDUFS6"  "NEDD8"   "TIMM8B"
# [29] "MYEOV2"  "NDUFA12" "NDUFC1"  "SHFM1"   "COX17"   "MIR4461" "NDUFAB1"
# [36] "NDUFB4"  "SEC61G"  "UBL5"    "APRT"    "RPS29"   "SNRPG"   "LGALS1"
# [43] "NHP2"    "SNRPF"   "PFDN2"   "LSM7"    "NDUFB8"  "NDUFA7"  "RPS21"
# [50] "COA3"
#
# $Cancer$`MP22 Secreted I`
#  [1] "CXCL8"     "PHLDA1"    "MAFF"      "KDM6B"     "EPHA2"     "ERRFI1"
#  [7] "IER3"      "TNFRSF12A" "PHLDA2"    "TM4SF1"    "TRIB1"     "DUSP5"
# [13] "FOSL1"     "HBEGF"     "ICAM1"     "AREG"      "BIRC3"     "CXCL1"
# [19] "EMP1"      "ITPKC"     "MIDN"      "PIM3"      "ARID5B"    "CCL2"
# [25] "CDKN1A"    "CSRNP1"    "CXCL2"     "MYC"       "ARL14"     "ARL5B"
# [31] "GEM"       "MYADM"     "PIM1"      "PLAUR"     "TNFAIP3"   "ANXA1"
# [37] "CCL20"     "CYR61"     "DDX21"     "EDN1"      "FOSL2"     "LIF"
# [43] "LUCAT1"    "MLF1"      "NAMPT"     "NCOA7"     "PFKFB3"    "ZBTB43"
# [49] "ZC3H12A"   "FHL2"
#
# $Cancer$`MP23 Secreted II`
#  [1] "LCN2"     "CP"       "WFDC2"    "AGR2"     "C3"       "CXCL1"
#  [7] "CXCL8"    "SAA1"     "CLU"      "MDK"      "TSPAN8"   "BPIFB1"
# [13] "CFB"      "KLK11"    "PDZK1IP1" "SAA2"     "SLPI"     "TSPAN1"
# [19] "CXCL2"    "ELF3"     "LTF"      "PIGR"     "SCGB3A1"  "TFF3"
# [25] "TGM2"     "AKR1C1"   "CD24"     "CLDN4"    "CTSC"     "GSTA1"
# [31] "KRT19"    "MMP7"     "MSMB"     "NCOA7"    "S100A9"   "SCGB1A1"
# [37] "SPINK1"   "IGFBP3"   "VMO1"     "MUC5B"    "SERPINF1" "TNFSF10"
# [43] "FMO2"     "FAM3D"    "PRSS23"   "RDH10"    "CD82"     "RARRES1"
# [49] "KYNU"     "NDRG2"
#
# $Cancer$`MP24 Cilia`
#  [1] "C9ORF116"     "CAPS"         "RSPH1"        "TPPP3"        "FAM183A"
#  [6] "MORN2"        "WDR54"        "CETN2"        "ODF3B"        "C9ORF24"
# [11] "PIFO"         "C11ORF88"     "C5ORF49"      "DYNLRB2"      "C1ORF194"
# [16] "EFHC1"        "FAM229B"      "IQCG"         "PSENEN"       "SPA17"
# [21] "TSPAN1"       "C20ORF85"     "DNALI1"       "FOXJ1"        "LRRC23"
# [26] "LRRIQ1"       "IGFBP7"       "MS4A8"        "TCTEX1D2"     "DPCD"
# [31] "KIF9"         "TUBA1A"       "FABP6"        "MRPS31"       "ZMYND10"
# [36] "C12ORF75"     "CAPSL"        "CES1"         "DNAAF1"       "IFT57"
# [41] "IGFBP2"       "MLF1"         "OSCP1"        "PLAC8"        "DNAH5"
# [46] "CRIP1"        "RP11-295M3.4" "GSTA1"        "SLC44A4"      "NUCB2"
#
# $Cancer$`MP25 Astrocytes`
#  [1] "SPARCL1" "GFAP"    "CLU"     "CRYAB"   "TTYH1"   "SLC1A3"  "CST3"
#  [8] "ID3"     "AGT"     "APOE"    "EDNRB"   "ALDOC"   "AQP4"    "GATM"
# [15] "NDRG2"   "SPARC"   "MT2A"    "MT3"     "BCAN"    "HEPN1"   "NTRK2"
# [22] "PMP2"    "PON2"    "ATP1A2"  "HEY1"    "MLC1"    "PLTP"    "ATP1B2"
# [29] "ITM2C"   "MT1X"    "VIM"     "S100B"   "AHCYL1"  "RAMP1"   "SCRG1"
# [36] "C1ORF61" "IGFBP7"  "RASSF4"  "ID1"     "IFITM3"  "CPE"     "CD9"
# [43] "FABP7"   "GRAMD3"  "ZFP36"   "F3"      "PLP1"    "ID4"     "PSAT1"
# [50] "GJA1"
#
# $Cancer$`MP26 NPC Glioma`
#  [1] "STMN2"        "DCX"          "STMN4"        "TAGLN3"       "ELAVL4"
#  [6] "MLLT11"       "NREP"         "MIAT"         "TUBB2A"       "CD24"
# [11] "HMP19"        "RND3"         "SOX11"        "SOX4"         "TUBB3"
# [16] "MAP1B"        "NSG1"         "SNAP25"       "FNBP1L"       "HN1"
# [21] "IGFBPL1"      "PKIA"         "NNAT"         "RBP1"         "SCG3"
# [26] "DLX6-AS1"     "KLHDC8A"      "MEG3"         "RBFOX2"       "SCG2"
# [31] "STMN1"        "TMEM161B-AS1" "ARL4D"        "BEX2"         "DDAH2"
# [36] "DLX5"         "GAP43"        "CRMP1"        "ENO2"         "TCEAL7"
# [41] "UCHL1"        "BASP1"        "CXADR"        "GNG3"         "GPC2"
# [46] "KIF5C"        "PAK3"         "RTN1"         "TERF2IP"      "SYT1"
#
# $Cancer$`MP27 Oligo Progenitor`
#  [1] "SIRT2"    "GPR17"    "OLIG1"    "APOD"     "DLL3"     "PLP1"
#  [7] "NEU4"     "BCAN"     "SOX8"     "TNR"      "OMG"      "TMEM206"
# [13] "LPPR1"    "NKAIN4"   "FIBIN"    "SGK1"     "SLC1A1"   "CA10"
# [19] "LMF1"     "PTGDS"    "SERINC5"  "ASCL1"    "DLL1"     "OLIG2"
# [25] "PSAT1"    "RAB33A"   "SCRG1"    "CNP"      "LIMA1"    "THY1"
# [31] "TUBB4A"   "BCAS1"    "CNTN1"    "HES6"     "LHFPL3"   "PDGFRA"
# [37] "RGR"      "SCD5"     "ANGPTL2"  "DHCR7"    "FGF12"    "MPZL1"
# [43] "MSMO1"    "P2RX7"    "RTKN"     "TNFRSF21" "SMOC1"    "ACAT2"
# [49] "FDFT1"    "PGRMC1"
#
# $Cancer$`MP28 Oligo normal`
#  [1] "APOD"     "MBP"      "PLA2G16"  "PLP1"     "PPP1R14A" "SEPP1"
#  [7] "TF"       "GSN"      "PTGDS"    "APLP1"    "CLDN11"   "CLDND1"
# [13] "CNP"      "RNASE1"   "SCD"      "44443"    "ANLN"     "CRYAB"
# [19] "ELOVL1"   "HSPA2"    "PLLP"     "SIRT2"    "SLC44A1"  "BIN1"
# [25] "CMTM5"    "ERMN"     "FAM107B"  "LARP6"    "LHPP"     "MAG"
# [31] "MOBP"     "PLEKHB1"  "QDPR"     "S100A1"   "SLAIN1"   "SLC48A1"
# [37] "TUBB4A"   "TMEM144"  "ABCA2"    "CA2"      "KLK6"     "MAL"
# [43] "SPOCK3"   "HAPLN2"   "UGT8"     "STMN4"    "ATP1B1"   "44447"
# [49] "PACS2"    "ANKS1B"
#
# $Cancer$`MP29 NPC/OPC`
#  [1] "BTG2"     "SOX6"     "BAZ2B"    "SOX4"     "DSEL"     "MXD4"
#  [7] "PNRC1"    "SOX5"     "CHD7"     "GRIA2"    "MAP3K1"   "OLIG1"
# [13] "SESN3"    "UBE2H"    "ABAT"     "DCX"      "DOCK10"   "GLCCI1"
# [19] "KCNQ1OT1" "KDM5B"    "KLHL24"   "MAP2"     "OLIG2"    "PEAK1"
# [25] "RAB3IP"   "RFTN2"    "RFX4"     "TANC2"    "TRIO"     "VCAN"
# [31] "ZNF91"    "FAM181B"  "STMN4"    "DLL3"     "BTG1"     "TXNIP"
# [37] "LDLRAD3"  "SOX11"    "HIP1"     "FGFBP3"   "MTSS1"    "SPRY4"
# [43] "REV3L"    "MMP16"    "KLF12"    "TFDP2"    "CADM2"    "ARHGEF7"
# [49] "GOLGB1"   "ZMYM2"
#
# $Cancer$`MP30 PDAC-classical`
#  [1] "TFF1"      "TFF3"      "CEACAM6"   "AGR2"      "LGALS4"    "PHGR1"
#  [7] "PLAC8"     "SLC40A1"   "TM4SF4"    "TSPAN8"    "ANXA10"    "LYZ"
# [13] "TFF2"      "CTSE"      "GCNT3"     "GPX2"      "MUC13"     "MUC5AC"
# [19] "MUC5B"     "PIGR"      "CEACAM5"   "CLDN18"    "FAM3D"     "SPINK1"
# [25] "AGR3"      "DUOX2"     "PLA2G10"   "REG4"      "DUOXA2"    "PDE4C"
# [31] "PSCA"      "TSPAN1"    "VSIG2"     "CA2"       "HPGD"      "DPCR1"
# [37] "OLFM4"     "AKR7A3"    "CDH17"     "FXYD3"     "PDZK1IP1"  "TCN1"
# [43] "CEACAM1"   "ISG20"     "LINC01133" "SLC44A4"   "VSIG1"     "CEACAM7"
# [49] "CXCL17"    "CES2"
#
# $Cancer$`MP31 Alveolar`
#  [1] "SFTPA1"   "SFTPA2"   "SFTPD"    "LRRK2"    "PGC"      "SFTPC"
#  [7] "C4BPA"    "SFTPB"    "AQP1"     "ABCA3"    "PEBP4"    "SCD"
# [13] "HSD17B6"  "MFSD2A"   "NAPSA"    "NNMT"     "PIGR"     "SCGB3A2"
# [19] "SERPINA1" "SPINK5"   "C16ORF89" "C3"       "CACNA2D2" "EPHX1"
# [25] "MID1IP1"  "RNASE1"   "ALPL"     "DHCR24"   "HOPX"     "LPCAT1"
# [31] "SCGB3A1"  "SFTA2"    "PTPN13"   "S100A9"   "SFTA3"    "SUSD2"
# [37] "DMBT1"    "NPC2"     "SLC22A31" "TFPI"     "ALOX15B"  "SLPI"
# [43] "SFTA1P"   "AK1"      "DUOX1"    "FASN"     "FABP5"    "CXCL17"
# [49] "SDR16C5"  "LAMP3"
#
# $Cancer$`MP32 Skin-pigmentation`
#  [1] "PHACTR1"   "TBC1D7"    "MLANA"     "ASAH1"     "DCT"       "LGALS3"
#  [7] "CAPN3"     "GDF15"     "GPNMB"     "GPR137B"   "MBP"       "MITF"
# [13] "PMEL"      "TNFRSF14"  "BIRC7"     "CHCHD6"    "LINC00518" "MXI1"
# [19] "NOV"       "TRPM1"     "APOE"      "FXYD3"     "ISG20"     "NBL1"
# [25] "PLP1"      "QDPR"      "QPCT"      "SH3BP5"    "TIMP2"     "TRIM2"
# [31] "AVPI1"     "DAB2"      "GJB1"      "GPR143"    "GYPC"      "LYST"
# [37] "NSG1"      "PIR"       "RAB38"     "RRAGD"     "S100B"     "SLC45A2"
# [43] "SNCA"      "TBC1D16"   "TYRP1"     "WIPI1"     "SPON2"     "ZNF106"
# [49] "BCL2A1"    "SNX10"
#
# $Cancer$`MP33 RBCs`
#  [1] "BLVRB"    "HBB"      "APOC1"    "CA1"      "HBD"      "AHSP"
#  [7] "PRDX2"    "REXO2"    "CNRIP1"   "HMBS"     "S100A6"   "HAGH"
# [13] "PLIN2"    "RHAG"     "CD36"     "FAM178B"  "FBXO7"    "FECH"
# [19] "HES6"     "KCNH2"    "KLF1"     "MYC"      "TFRC"     "ANK1"
# [25] "APOE"     "CASP3"    "CAST"     "HBA1"     "HBG2"     "MPC2"
# [31] "NFIA"     "STRADB"   "SYNGR1"   "TFR2"     "TMEM14C"  "UBAC1"
# [37] "CA2"      "GATA1"    "GYPB"     "HBA2"     "HBQ1"     "SMIM10"
# [43] "EPCAM"    "FAM45A"   "FCGRT"    "SLC25A37" "LMNA"     "HBG1"
# [49] "UROD"     "CSF2RB"
#
# $Cancer$`MP34 Platelet-activation`
#  [1] "RGS18"         "PDLIM1"        "ITGA2B"        "PLEK"
#  [5] "C6ORF25"       "FERMT3"        "RAP1B"         "CLU"
#  [9] "LIMS1"         "CD9"           "NRGN"          "PBX1"
# [13] "PF4"           "PKM"           "RP11-354E11.2" "SDPR"
# [17] "SLC44A1"       "STOM"          "TMSB4X"        "C2ORF88"
# [21] "CMTM5"         "GP9"           "GSN"           "HBD"
# [25] "LAT"           "MAX"           "VCL"           "ACTN1"
# [29] "DAD1"          "FYB"           "MGLL"          "MMRN1"
# [33] "PPIF"          "TPM1"          "BIN2"          "CCND3"
# [37] "FCER1A"        "FCER1G"        "FLI1"          "GATA2"
# [41] "GUCY1B3"       "PRKAR2B"       "TGFB1"         "TPM4"
# [45] "VASP"          "RAB27B"        "PIM1"          "CD36"
# [49] "LGALS1"        "CKB"
#
# $Cancer$`MP35 Hemato-related-I`
#  [1] "CSF3R"    "SPINK2"   "VAMP5"    "AZU1"     "SELL"     "C1QTNF4"
#  [7] "CFD"      "CTSG"     "ELANE"    "HOPX"     "ITM2C"    "NPDC1"
# [13] "AVP"      "C1ORF228" "CD52"     "CLEC11A"  "CRHBP"    "CST7"
# [19] "MBOAT7"   "MDK"      "PLAC8"    "PRTN3"    "RNASE2"   "BAALC"
# [25] "BST2"     "C19ORF77" "CD44"     "GLIPR1"   "ICAM3"    "KLF6"
# [31] "MPO"      "MS4A3"    "PRSS57"   "RAB32"    "SRGN"     "TSC22D3"
# [37] "ZFP36L2"  "FOS"      "SERPINB1" "IGLL1"    "LYZ"      "MGST1"
# [43] "TNFSF13B" "HLA-DQB1" "CD74"     "PTPRCAP"  "ANKRD28"  "CD34"
# [49] "CPA3"     "KIAA0125"
#
# $Cancer$`MP36 IG`
#  [1] "IGLC2"      "IGLC3"      "IGHA2"      "IGHA1"      "IGHG4"
#  [6] "IGKC"       "CD79A"      "IGHG1"      "IGHG3"      "IGHG2"
# [11] "IGHGP"      "IGLJ2"      "IGLC1"      "DERL3"      "IGHM"
# [16] "IGLC7"      "SELENOM"    "CD63"       "IGLV3-1"    "IGLV3-7"
# [21] "IGLV6-57"   "JSRP1"      "CCPG1"      "DNAJB9"     "IGKV1-12"
# [26] "IGLJ1"      "KLF6"       "TSC22D3"    "AC134669.2" "ADA2"
# [31] "CD27"       "CITED2"     "FCRL5"      "HERPUD1"    "HLA-F"
# [36] "IGKV4-1"    "IGLC5"      "IGLC6"      "IGLJ3"      "IGLL5"
# [41] "IGLV3-21"   "ITGB7"      "JCHAIN"     "TXNIP"      "MIR4539"
# [46] "SEL1L3"     "PRDX4"      "IRF4"       "MAN1A2"     "TNFRSF17"
#
# $Cancer$`MP37 Hemato-related-II`
#  [1] "CTNNBL1"       "FCER1A"        "GATA2"         "CD84"
#  [5] "PDZD8"         "SLC40A1"       "TESPA1"        "ZMYND8"
#  [9] "CYTL1"         "MINPP1"        "PDCD4"         "PKIG"
# [13] "RP11-354E11.2" "SOD2"          "STAM"          "ABCC4"
# [17] "ALDH1A1"       "ATP6V0A2"      "CD82"          "CNRIP1"
# [21] "CPA3"          "CPPED1"        "DEPTOR"        "GMPR"
# [25] "HBD"           "HPGDS"         "IL1B"          "KLF1"
# [29] "LXN"           "NFE2"          "PLEK"          "PLIN2"
# [33] "RAB37"         "RGS18"         "TPSB2"         "ZEB2"
# [37] "STXBP6"        "KCNQ1OT1"      "BMP2K"         "EREG"
# [41] "LINC00152"     "FREM1"         "PBX1"          "PDLIM1"
# [45] "MPP1"          "SOX4"          "FAM117A"       "FAM19A2"
# [49] "ICAM4"         "CASP3"
#
# $Cancer$`MP38 Glutathione`
#  [1] "NAT8"     "ACSM2B"   "LGALS2"   "AMN"      "BBOX1"    "KHK"
#  [7] "MIOX"     "SMIM24"   "AQP1"     "C11ORF54" "CUBN"     "GSTA1"
# [13] "GLYAT"    "ACSM2A"   "AOC1"     "APOM"     "GAL3ST1"  "GSTA2"
# [19] "SLC6A13"  "AZGP1"    "GLYATL1"  "LRP2"     "PCSK1N"   "PEPD"
# [25] "SLC17A3"  "SLC5A12"  "CDHR5"    "MSRA"     "PDZK1"    "PXMP2"
# [31] "SLC16A9"  "SLC22A18" "AGT"      "CES2"     "CLDN10"   "DDC"
# [37] "TMEM27"   "TNFAIP6"  "AGXT2"    "CFI"      "FOLR1"    "GAMT"
# [43] "HRSP12"   "RBP5"     "TSPAN1"   "GPX3"     "CXCL14"   "PRAP1"
# [49] "LACTB2"   "GCHFR"
#
# $Cancer$`MP39 Metal-response`
#  [1] "MT1X"         "CAV1"         "MT1E"         "C5ORF46"      "TGFBI"
#  [6] "CEBPB"        "CKB"          "EPB41L4A-AS1" "IGFBP5"       "LGALS1"
# [11] "LOX"          "MT1M"         "MT2A"         "MT3"          "NOL3"
# [16] "STC1"         "TUBA1A"       "C10ORF10"     "C1S"          "CP"
# [21] "DDIT4"        "EMP3"         "GLUL"         "MT1F"         "NPTX2"
# [26] "PLP2"         "SMIM3"        "SNHG7"        "SOX4"         "BGN"
# [31] "EDN1"         "ID1"          "ID4"          "IER2"         "MT1A"
# [36] "PMP22"        "RSL24D1"      "TSC22D3"      "VCAM1"        "VCAN"
# [41] "FSTL3"        "TMEM45A"      "ZBTB16"       "TMEM91"       "FKBP5"
# [46] "S100A6"       "C1R"          "MMP7"         "KLF4"         "ANXA1"
#
# $Cancer$`MP40 PDAC-related`
#  [1] "ISG20"     "KLK10"     "CEACAM1"   "F3"        "LMO7"      "PLAUR"
#  [7] "SLPI"      "ANKRD36C"  "CD55"      "CEACAM6"   "EPS8L1"    "LCN2"
# [13] "PSCA"      "TIMP2"     "C15ORF48"  "KLF2"      "KLK6"      "KLK7"
# [19] "KRT23"     "LAMC2"     "S100A4"    "TNFRSF12A" "ALDH1A3"   "ANXA1"
# [25] "APOL1"     "CLDN23"    "CLIC3"     "COL6A1"    "CST6"      "EMP1"
# [31] "FLNB"      "IL1RN"     "IL32"      "KLK11"     "KRT16"     "KRT17"
# [37] "LDLR"      "MALL"      "MMP7"      "RAB11FIP1" "SLC16A3"   "TFF2"
# [43] "CEACAM5"   "MUC5AC"    "SDCBP2"    "SMIM5"     "ISG15"     "SLC2A1"
# [49] "LRRC8A"    "MT1X"
#
# $Cancer$`MP41 Unassigned`
#  [1] "DST"        "KMT2A"      "MALAT1"     "MIR6515"    "AKAP9"
#  [6] "ATRX"       "GOLGB1"     "ZBTB20"     "EIF3A"      "MIR3648-1"
# [11] "ANKRD12"    "GOLGA4"     "HNRNPU"     "HSP90B2P"   "PRRC2C"
# [16] "RRBP1"      "TTC3"       "CFLAR"      "DDX24"      "EPRS"
# [21] "FNDC3B"     "HSP90B3P"   "IRF4"       "MLEC"       "MT-ND6"
# [26] "NCL"        "NEAT1"      "NEB"        "PNISR"      "PNRC1"
# [31] "SNORD18B"   "UBXN4"      "AC010343.1" "BPTF"       "CCDC69"
# [36] "CEP350"     "DDX5"       "EIF5B"      "GLCCI1"     "HIPK2"
# [41] "KMT2C"      "LUC7L3"     "MEF2C"      "PDIA4"      "SNORD55"
# [46] "SNORD68"    "SON"        "UTRN"       "ZBTB38"     "XIST"
#
#
# $Endothelial
# $Endothelial$`MP1 Notch-signaling`
#  [1] "IGFBP3"   "SEMA3G"   "EFNB2"    "ARL15"    "FBLN5"    "GJA4"
#  [7] "CXCL12"   "GJA5"     "CLDN5"    "HEY1"     "ENPP2"    "KCTD12"
# [13] "SRGN"     "SAT1"     "IGF2"     "PPA1"     "MECOM"    "PLPP1"
# [19] "SLC9A3R2" "C10ORF10" "STC1"     "ADAMTS1"  "LTBP4"    "FN1"
# [25] "JAG1"     "EDN1"     "HES4"     "THSD7A"   "S100A4"   "STMN1"
# [31] "NUDT4"    "SULF1"    "CXCL2"    "DLL4"     "PLLP"     "ADAMTS6"
# [37] "ICAM2"    "SOX17"    "FBLN2"    "JAG2"     "PCSK5"    "VEGFC"
# [43] "PPP1R14A" "RHOB"     "SERPINE2" "ATP13A3"  "PODXL"    "FAM107A"
# [49] "EMP3"     "ALPL"
#
# $Endothelial$`MP2 MHC-II/Secreted`
#  [1] "ACKR1"    "CLU"      "SELP"     "ADIRF"    "DUSP23"   "NNMT"
#  [7] "PRCP"     "CCL14"    "NR2F2"    "SELE"     "IL33"     "IL1R1"
# [13] "HLA-DRA"  "NPC2"     "ZNF385D"  "POSTN"    "CPE"      "ACTN1"
# [19] "HLA-DPA1" "HLA-DPB1" "PTGDS"    "TSPAN7"   "VCAM1"    "TFPI"
# [25] "ARL4A"    "MMRN1"    "NCOA7"    "VWF"      "C7"       "CD74"
# [31] "HLA-DQA1" "IER3"     "HLA-DRB1" "CCL2"     "HAPLN3"   "ICAM1"
# [37] "SNCG"     "SOD2"     "LIFR"     "HLA-DMA"  "SLCO2A1"  "CEBPD"
# [43] "HLA-DRB5" "MGP"      "CXCL2"    "CYP1B1"   "HLA-DQB1" "PLAT"
# [49] "RAMP3"    "FBLN2"
#
# $Endothelial$`MP3 Endo1`
#  [1] "INSR"        "RGCC"        "COL4A1"      "FLT1"        "ESM1"
#  [6] "IGFBP3"      "COL4A2"      "IVNS1ABP"    "ANGPT2"      "KDR"
# [11] "STC1"        "NOTCH4"      "CA2"         "PLVAP"       "VWA1"
# [16] "COL15A1"     "PODXL"       "MCAM"        "TIMP3"       "TM4SF18"
# [21] "GRB10"       "ITGA1"       "LBH"         "EDNRB"       "FCN3"
# [26] "TP53I11"     "SPARC"       "CXCR4"       "GJA1"        "MYO1B"
# [31] "MIR4435-2HG" "MLEC"        "PLPP3"       "TNFRSF4"     "ANGPTL2"
# [36] "PTP4A3"      "HSPG2"       "HECW2"       "PDGFD"       "PXDN"
# [41] "ADGRF5"      "LAMA4"       "MMP2"        "SLC9A3R2"    "SPRY4"
# [46] "CDH13"       "ACE"         "HTRA1"       "UNC5B"       "NID1"
#
# $Endothelial$`MP4 Stress`
#  [1] "EGR1"      "SOCS3"     "CDKN1A"    "FOSB"      "JUNB"      "ZFP36"
#  [7] "GADD45B"   "IRF1"      "DNAJB1"    "PPP1R15A"  "FOS"       "JUN"
# [13] "ATF3"      "DNAJA1"    "ICAM1"     "NFKBIZ"    "RND1"      "IER3"
# [19] "SERTAD1"   "KLF4"      "CXCL2"     "HSPA1A"    "NR4A1"     "SLC2A3"
# [25] "HES1"      "HSPH1"     "IER2"      "MAFF"      "BTG2"      "CCL2"
# [31] "HSPA1B"    "SOD2"      "BAG3"      "KDM6B"     "NFKBIA"    "TNFRSF10D"
# [37] "CCNL1"     "HEXIM1"    "ADAMTS1"   "JUND"      "C11ORF96"  "MCL1"
# [43] "MIDN"      "ZC3HAV1"   "APOLD1"    "CSRNP1"    "FOSL2"     "BRD2"
# [49] "BHLHE40"   "ARID5A"
#
# $Endothelial$`MP5 Endo2`
#  [1] "TFF3"    "CCL21"   "MMRN1"   "FABP4"   "FABP5"   "GYPC"    "LAPTM5"
#  [8] "PDPN"    "TFPI"    "PROX1"   "EFEMP1"  "AKAP12"  "PPFIBP1" "LYVE1"
# [15] "RBP1"    "NRP2"    "FXYD6"   "FLT4"    "MAF"     "PPP1R2"  "ADD3"
# [22] "APOD"    "CD9"     "CLDN5"   "NR2F2"   "FN1"     "NTS"     "STMN1"
# [29] "TSTA3"   "IGFBP5"  "ADIRF"   "ANGPT2"  "ARL4A"   "IGF1"    "RGS16"
# [36] "TSPAN5"  "LIMS1"   "MFAP2"   "PTPRE"   "SNCG"    "CLU"     "SEMA3A"
# [43] "MRC1"    "RARRES2" "RELN"    "CCDC80"  "NR2F1"   "TIMP1"   "PARD6G"
# [50] "CISD1"
#
# $Endothelial$`MP6 Cell-cycle`
#  [1] "HMGB2"    "CKS1B"    "STMN1"    "HIST1H4C" "PTTG1"    "TYMS"
#  [7] "SMC4"     "TUBA1B"   "PCNA"     "CENPF"    "KIAA0101" "TOP2A"
# [13] "TUBB"     "TK1"      "H2AFZ"    "NUSAP1"   "UBE2C"    "BIRC5"
# [19] "CDK1"     "CENPW"    "DTYMK"    "DUT"      "MKI67"    "CKS2"
# [25] "GGH"      "HMGN2"    "KPNA2"    "RPA3"     "RRM2"     "UBE2S"
# [31] "ANP32E"   "SMC2"     "TUBB4B"   "ZWINT"    "TUBA1C"   "UBE2T"
# [37] "CDKN3"    "H2AFX"    "KIF22"    "KIF20B"   "MAD2L1"   "PRC1"
# [43] "TMPO"     "CKAP2"    "TMEM106C" "ASPM"     "MCM7"     "CLSPN"
# [49] "SKA2"     "CENPM"
#
# $Endothelial$`MP7 Endo3`
#  [1] "VWF"     "RGCC"    "RNASE1"  "CLDN5"   "ENG"     "EPAS1"   "CD93"
#  [8] "FCN3"    "MT1M"    "PTPRB"   "RAMP3"   "SPARCL1" "TMEM100" "AQP1"
# [15] "HYAL2"   "A2M"     "CA4"     "CALCRL"  "CLEC14A" "GPX3"    "IFI27"
# [22] "MT1X"    "BTNL9"   "EDN1"    "MT1E"    "PECAM1"  "GNG11"   "HSPG2"
# [29] "ID1"     "IL7R"    "RAMP2"   "PLVAP"   "CD36"    "EGFL7"   "IGFBP7"
# [36] "LIFR"    "MT2A"    "SDPR"    "TNFSF10" "ESAM"    "FAM107A" "GIMAP7"
# [43] "GPIHBP1" "IFNGR1"  "NOTCH4"  "SPARC"   "TM4SF1"  "SLC6A4"  "C8ORF4"
# [50] "MGP"
#
# $Endothelial$`MP8 Endo4`
#  [1] "CRHBP"     "EMCN"      "FCN3"      "IGFBP5"    "PLAT"      "SOST"
#  [7] "PLPP3"     "EHD3"      "MGP"       "TGFBR2"    "MEG3"      "NTN4"
# [13] "SYNE1"     "TSPAN7"    "KDR"       "PRX"       "F8"        "SLC14A1"
# [19] "HECW2"     "LDB2"      "TMEM204"   "AQP1"      "CMTM8"     "ITGA8"
# [25] "ARRDC2"    "BTNL9"     "FLT1"      "LGALS3BP"  "NOSTRIN"   "NRP1"
# [31] "SGK1"      "COL4A1"    "GMFG"      "EFNB1"     "ESM1"      "LINC00551"
# [37] "PLPP1"     "S100A4"    "TBX3"      "ADGRF5"    "ARHGDIB"   "CEBPB"
# [43] "GJA5"      "ID2"       "IL1RL1"    "RBMS1"     "SLC44A1"   "FGL2"
# [49] "IL13RA2"   "POMP"
#
# $Endothelial$`MP9 Endo5`
#  [1] "PGF"       "CTHRC1"    "PXDN"      "IL32"      "LXN"       "ADM"
#  [7] "APOD"      "LGALS1"    "LOX"       "TP53I11"   "CLDN5"     "GYPC"
# [13] "CHST15"    "CYTL1"     "HOMER3"    "MCAM"      "NID2"      "WFS1"
# [19] "CHST1"     "CXCR4"     "GPIHBP1"   "LY6H"      "TNFAIP8L1" "TNFRSF4"
# [25] "TSPAN15"   "FABP5"     "IGF2"      "LAMA4"     "RGCC"      "RGS3"
# [31] "EIF4EBP1"  "FSCN1"     "MGLL"      "MMP2"      "SLC38A1"   "C10ORF10"
# [37] "COL4A1"    "COTL1"     "EFCAB14"   "ESM1"      "GMFG"      "JUP"
# [43] "PDGFB"     "RND3"      "SLC4A7"    "SMTN"      "COL12A1"   "SMAD1"
# [49] "PCDH12"    "MARCKS"
#
# $Endothelial$`MP10 Interferon`
#  [1] "GBP1"     "GBP4"     "IFIT3"    "IFIT1"    "TNFSF10"  "ISG15"
#  [7] "IFI44L"   "MX2"      "IFI6"     "MX1"      "CXCL11"   "WARS"
# [13] "EPSTI1"   "IFI35"    "LY6E"     "UBE2L6"   "BST2"     "ISG20"
# [19] "LAP3"     "OAS1"     "OAS2"     "OAS3"     "PARP14"   "RSAD2"
# [25] "STAT1"    "APOL6"    "IFI44"    "IFIT2"    "IRF7"     "NT5C3A"
# [31] "SAMHD1"   "SERPING1" "TAP1"     "TRIM22"   "CMPK2"    "EIF2AK2"
# [37] "GBP2"     "MT2A"     "RARRES3"  "SAMD9"    "SAMD9L"   "APOL2"
# [43] "CXCL10"   "HAPLN3"   "IRF1"     "XAF1"     "DDX58"    "TAP2"
# [49] "USP18"    "PPM1K"
#
# $Endothelial$`MP11 Endo6`
#  [1] "IGFBP5"  "APLNR"   "NR2F2"   "SLCO2A1" "PRCP"    "ADAMTS1" "HEG1"
#  [8] "MALL"    "SELP"    "SELE"    "TGM2"    "VCAN"    "SLC6A6"  "STC1"
# [15] "TNXB"    "ACKR1"   "ADAM15"  "EMP3"    "NDRG1"   "NOS3"    "RAMP3"
# [22] "THBD"    "ADAMTS6" "ADIRF"   "DUSP23"  "FN1"     "MARCKS"  "PGM5"
# [29] "PTGDS"   "VCAM1"   "VEGFC"   "EHBP1L1" "EPHB4"   "FBLN2"   "HYAL2"
# [36] "ITGA6"   "SEMA3F"  "TEK"     "APOL1"   "CALCRL"  "ENTPD1"  "PLEC"
# [43] "SPTAN1"  "TSHZ2"   "PLAC9"   "KLF2"    "PCDH12"  "VWF"     "CRIP1"
# [50] "PCDH17"
#
# $Endothelial$`MP12 Endo7`
#  [1] "HPGD"     "S100A4"   "CA4"      "EDNRB"    "LGALS1"   "ADIRF"
#  [7] "IL1RL1"   "TUBA1A"   "EMCN"     "FRY"      "IL32"     "SOSTDC1"
# [13] "ICAM2"    "PRX"      "ACE"      "DNAJC1"   "EMP2"     "HLA-DQA1"
# [19] "S100A3"   "SERPINB1" "SGK1"     "TMEM204"  "APP"      "CAV2"
# [25] "FENDRR"   "SLC14A1"  "SLC9A3R2" "CYP3A5"   "TSPAN12"  "CARD16"
# [31] "CD82"     "CNN3"     "MARCKS"   "MYLK"     "SERPINB6" "SERPINE1"
# [37] "TMEM100"  "ITM2A"    "SPARCL1"  "TSPAN15"  "ANXA3"    "HLA-DMA"
# [43] "ANXA1"    "RPN1"     "C10ORF10" "HLA-DQB1" "SPARC"    "TYMP"
# [49] "GNG11"    "CAPZA2"
#
# $Endothelial$`MP13 Endo8`
#  [1] "RGCC"     "ID2"      "SGK1"     "TM4SF18"  "TMEM88"   "RBP7"
#  [7] "CD36"     "F2RL3"    "MT1M"     "MT1X"     "MT1E"     "RAMP3"
# [13] "TMEM204"  "BTNL9"    "CA4"      "DHRS3"    "DNASE1L3" "FAM167B"
# [19] "FCN3"     "HES1"     "MT2A"     "NOSTRIN"  "PLPP3"    "SLC9A3R2"
# [25] "STC1"     "ATOH8"    "CARHSP1"  "CD320"    "CDC42EP4" "COL15A1"
# [31] "DDIT4"    "EDNRB"    "ITM2A"    "NQO1"     "OSBPL1A"  "SELENOP"
# [37] "SPP1"     "GAS6"     "FXYD6"    "VWA1"     "GYPC"     "NOTCH4"
# [43] "PLPP1"    "HLA-DQA1" "AKAP12"   "SIPA1L2"  "CTSH"     "TSC22D1"
# [49] "NKX2-3"   "MLEC"
#
# $Endothelial$`MP14 NF-kb`
#  [1] "SELE"     "ACKR1"    "SOD2"     "AKAP12"   "CCL2"     "EMP1"
#  [7] "PNP"      "ICAM1"    "VCAM1"    "ADAMTS9"  "CXCL2"    "GJA1"
# [13] "HIF1A"    "IL6"      "NDRG1"    "NFKBIA"   "ABL2"     "BIRC3"
# [19] "C11ORF96" "CSF3"     "CXCL8"    "DDX21"    "LITAF"    "MYC"
# [25] "NAMPT"    "NNMT"     "PMP22"    "SERPINB1" "TIMP1"    "TNFAIP3"
# [31] "RND1"     "PLVAP"    "MT1A"     "ISG20"    "CLU"      "IER3"
# [37] "ARID5A"   "TMEM70"   "PTPRE"    "CDKN1A"   "UGCG"     "NCOA7"
# [43] "TUBB6"    "C2CD4B"   "LMNA"     "ADAMTS4"  "ETS2"     "POSTN"
# [49] "IGFBP7"   "THBS1"
#
# $Endothelial$`MP15 Coagulation`
#  [1] "FN1"      "PMP22"    "TFPI"     "DNASE1L3" "IGFBP7"   "MARCKS"
#  [7] "PLVAP"    "COTL1"    "FABP5"    "FAM167B"  "HTRA1"    "S100A10"
# [13] "SNCG"     "TFF3"     "VCAM1"    "ACTN1"    "ADIRF"    "AHNAK"
# [19] "ANAPC16"  "BGN"      "CALM3"    "CCL14"    "CLU"      "CYR61"
# [25] "EFEMP1"   "LDB2"     "MEF2C"    "MIF"      "MPZL2"    "MRPL20"
# [31] "NFIB"     "NRP2"     "PRCP"     "PRDX5"    "QSOX1"    "RBP5"
# [37] "RGCC"     "SPARCL1"  "TM4SF18"  "TSPO"     "VWF"      "FXYD5"
# [43] "NUPR1"    "S100A4"   "ARL4A"    "CST3"     "RPS27L"   "DDIT4"
# [49] "DAD1"     "LGALS1"
#
#
# $Epithelial
# $Epithelial$`MP1 Stress`
#  [1] "EGR1"     "FOS"      "JUN"      "ATF3"     "JUNB"     "FOSB"
#  [7] "ZFP36"    "KLF6"     "DUSP1"    "CYR61"    "ELF3"     "IER2"
# [13] "BTG2"     "NFKBIA"   "NR4A1"    "CXCL2"    "HES1"     "CCNL1"
# [19] "PPP1R15A" "GADD45B"  "CLU"      "ERRFI1"   "ZFP36L1"  "NEAT1"
# [25] "IER3"     "MAFF"     "SOX4"     "RHOB"     "MALAT1"   "BCAM"
# [31] "KRT17"    "TACSTD2"  "CLDN4"    "DNAJB1"   "GDF15"    "TSC22D1"
# [37] "KLF4"     "KRT15"    "KRT19"    "JUND"     "SOCS3"    "WSB1"
# [43] "CEBPD"    "ID1"      "VMP1"     "CXCL8"    "IRF1"     "CXCL1"
# [49] "ZFP36L2"  "NCOA7"
#
# $Epithelial$`MP2 Secreted`
#  [1] "SLPI"     "WFDC2"    "LCN2"     "SCGB3A1"  "CP"       "PIGR"
#  [7] "AGR2"     "CXCL1"    "BPIFB1"   "KRT7"     "RARRES1"  "SAA1"
# [13] "MMP7"     "CXCL17"   "S100P"    "C3"       "MDK"      "TFF3"
# [19] "TSPAN1"   "TMEM45A"  "KLK11"    "LTF"      "TGM2"     "TSPAN8"
# [25] "FAM3D"    "MSMB"     "MUC5B"    "SCGB1A1"  "AKR1C1"   "CXCL8"
# [31] "RHOV"     "XBP1"     "CLU"      "CTSC"     "SERPINB3" "KRT19"
# [37] "ZG16B"    "CXCL6"    "GSTA1"    "IGFBP3"   "MGP"      "SAA2"
# [43] "VMO1"     "CEACAM6"  "PRSS23"   "S100A9"   "PSCA"     "AQP5"
# [49] "CYP2F1"   "ELF3"
#
# $Epithelial$`MP3 Alveolar`
#  [1] "NAPSA"    "SFTPA1"   "SFTPA2"   "SFTPB"    "SFTPC"    "NPC2"
#  [7] "SFTPD"    "CTSH"     "PGC"      "SLC34A2"  "FABP5"    "SCGB3A2"
# [13] "SERPINA1" "C16ORF89" "C4BPA"    "CXCL17"   "SFTA2"    "HLA-DPA1"
# [19] "RNASE1"   "SLPI"     "HLA-DPB1" "ABCA3"    "C3"       "LRRK2"
# [25] "CD74"     "DBI"      "HLA-DRB1" "LPCAT1"   "NNMT"     "LAMP3"
# [31] "MUC1"     "PIGR"     "SFTA3"    "HOPX"     "HLA-DRA"  "PEBP4"
# [37] "WIF1"     "C8ORF4"   "CXCL2"    "ALPL"     "SCGB3A1"  "TFPI"
# [43] "AK1"      "AQP1"     "MALL"     "PLA2G1B"  "AQP3"     "CA2"
# [49] "MFSD2A"   "CYB5A"
#
# $Epithelial$`MP4 Cilia`
#  [1] "TPPP3"    "CAPS"     "CETN2"    "PIFO"     "C20ORF85" "C9ORF24"
#  [7] "MORN2"    "RSPH1"    "FAM183A"  "TSPAN1"   "C5ORF49"  "C9ORF116"
# [13] "C1ORF194" "ODF3B"    "FAM229B"  "DYNLRB2"  "SNTN"     "C11ORF88"
# [19] "CAPSL"    "LRRIQ1"   "MRPS31"   "PSENEN"   "ZMYND10"  "MS4A8"
# [25] "WDR54"    "FOXJ1"    "IGFBP7"   "CCDC78"   "DNAAF1"   "MORN5"
# [31] "TUBA1A"   "C12ORF75" "CCDC146"  "CFAP126"  "KIF9"     "EFHC1"
# [37] "FAM92B"   "TMEM190"  "CFAP53"   "CRIP1"    "TCTEX1D2" "C2ORF40"
# [43] "AGR3"     "CCDC170"  "DYNLL1"   "OMG"      "CES1"     "TUBB4B"
# [49] "IK"       "TEKT1"
#
# $Epithelial$`MP5 Cell-cycle`
#  [1] "HMGB2"    "STMN1"    "UBE2C"    "CKS2"     "BIRC5"    "CENPW"
#  [7] "CKS1B"    "TUBA1B"   "TK1"      "CCNB1"    "CENPF"    "H2AFZ"
# [13] "PTTG1"    "SMC4"     "TOP2A"    "CDK1"     "HMGN2"    "MAD2L1"
# [19] "NUSAP1"   "KIAA0101" "PRC1"     "TYMS"     "CDC20"    "HIST1H4C"
# [25] "SMC2"     "MKI67"    "KIF20B"   "TUBB"     "ZWINT"    "CDKN3"
# [31] "PCNA"     "CCNB2"    "DTYMK"    "CCDC34"   "UBE2S"    "KPNA2"
# [37] "TPX2"     "UBE2T"    "ANP32E"   "DEK"      "H2AFV"    "HMGB3"
# [43] "RRM2"     "TMPO"     "ASPM"     "CENPU"    "DUT"      "NUDT1"
# [49] "RPA3"     "TUBB4B"
#
# $Epithelial$`MP6 EpiSen`
#  [1] "S100A8"    "S100A9"    "KRT6A"     "FABP5"     "KRT16"     "KRT6B"
#  [7] "LYPD3"     "SPRR1B"    "SBSN"      "KRT13"     "LY6D"      "SPINK5"
# [13] "CSTA"      "GLTP"      "SLPI"      "KRTDAP"    "S100A7"    "SULT2B1"
# [19] "DSC2"      "CALML3"    "CRABP2"    "SERPINB3"  "DMKN"      "GJB2"
# [25] "KLK11"     "SERPINB1"  "CALML5"    "SERPINB4"  "CLDN4"     "IL1RN"
# [31] "KRT4"      "KRT6C"     "PDZK1IP1"  "RHCG"      "CD24"      "CLIC3"
# [37] "IVL"       "AKR1B10"   "AQP3"      "C10ORF99"  "CSTB"      "MAL2"
# [43] "PKP1"      "TMEM45A"   "KRT10"     "RAB25"     "SERPINB13" "SPRR1A"
# [49] "TMEM40"    "KRT1"
#
# $Epithelial$`MP7 V-ATPase`
#  [1] "TMEM213"   "ATP6AP2"   "LGALS3"    "ATP6V1B1"  "ATP6V1G3"  "ATP6V0D2"
#  [7] "CD9"       "CLCNKB"    "ATP6V0B"   "CA12"      "IL18"      "C12ORF75"
# [13] "DHRS7"     "FAM24B"    "IGFBP5"    "CLCNKA"    "ATP6V0A4"  "EPS8"
# [19] "MAL"       "PTGER3"    "SMIM24"    "ARHGAP18"  "ATP6V1C2"  "BSG"
# [25] "EPCAM"     "LINC01187" "MALAT1"    "RTN4"      "SCIN"      "SMIM6"
# [31] "RARRES3"   "RHCG"      "SLC25A39"  "CTSD"      "SLC26A7"   "ATP6V1A"
# [37] "HLA-C"     "LITAF"     "RCAN2"     "TFCP2L1"   "TMSB4X"    "CA2"
# [43] "CLNK"      "DSG2"      "HEPACAM2"  "HLA-B"     "IGFBP7"    "ITGA6"
# [49] "ADGRF5"    "MT-ND3"
#
# $Epithelial$`MP8 Metabolism-Kidney1`
#  [1] "GLYAT"    "UGT2B7"   "NAT8"     "DAB2"     "LGALS2"   "PDZK1IP1"
#  [7] "BHMT"     "C11ORF54" "SLC3A1"   "ALDOB"    "BBOX1"    "CRYAB"
# [13] "MIOX"     "PCK1"     "PDZK1"    "ACSM2B"   "APOE"     "ACSM2A"
# [19] "CUBN"     "HRSP12"   "IL32"     "RBP5"     "TMEM27"   "CXCL14"
# [25] "GATM"     "GSTA1"    "MGST1"    "PEPD"     "AKR1C3"   "DPEP1"
# [31] "MT1F"     "MT1G"     "SPP1"     "HPD"      "MT1H"     "MT1X"
# [37] "SMIM24"   "AKR1A1"   "FABP1"    "HAO2"     "LRP2"     "OCIAD2"
# [43] "SLC5A12"  "AZGP1"    "GLYATL1"  "KHK"      "NEAT1"    "SLC16A9"
# [49] "TSPAN1"   "TMEM176A"
#
# $Epithelial$`MP9 Epi1`
#  [1] "AGER"      "CAV1"      "EMP2"      "CAV2"      "ANXA3"     "CYP4B1"
#  [7] "RTKN2"     "CLIC3"     "SPOCK2"    "MYL9"      "GPRC5A"    "IGFBP7"
# [13] "KRT7"      "TNNC1"     "TSPAN13"   "CEACAM6"   "LMO7"      "RAB11FIP1"
# [19] "RGCC"      "CLDN18"    "TIMP3"     "ADIRF"     "CLIC5"     "SCEL"
# [25] "AQP4"      "CST6"      "GAS6"      "IL32"      "SEMA3B"    "UPK3B"
# [31] "ANXA2"     "IFI27"     "VEGFA"     "CD55"      "S100A10"   "C19ORF33"
# [37] "PDLIM2"    "SLC39A8"   "AHNAK"     "ANKRD29"   "CD151"     "GGTLC1"
# [43] "KRT19"     "ANOS1"     "RDX"       "S100A4"    "SPARC"     "SUSD2"
# [49] "LIMCH1"    "FMO2"
#
# $Epithelial$`MP10 Interferon/MHC`
#  [1] "IFI27"    "IFITM3"   "CD74"     "GNG11"    "SLC9A3R2" "HLA-B"
#  [7] "HLA-DRA"  "RAMP2"    "TMSB4X"   "HLA-C"    "IFITM2"   "IGFBP5"
# [13] "MGP"      "VIM"      "B2M"      "EMCN"     "FKBP1A"   "HLA-A"
# [19] "HLA-DRB1" "TM4SF1"   "TMSB10"   "DUSP1"    "RNASE1"   "VAMP5"
# [25] "BST2"     "HLA-DPA1" "HLA-E"    "SPARC"    "ID1"      "LGALS1"
# [31] "MT2A"     "MYL12A"   "TIMP3"    "ANXA2"    "EPAS1"    "PLPP3"
# [37] "RAMP3"    "GIMAP7"   "HLA-DRB5" "IFITM1"   "IGFBP7"   "A2M"
# [43] "CRIP2"    "HLA-DPB1" "ID3"      "PLAT"     "TSC22D1"  "SDPR"
# [49] "CRHBP"    "ENG"
#
# $Epithelial$`MP11 EMT-like1`
#  [1] "DST"       "KRT15"     "KRT17"     "CAV1"      "S100A2"    "MT2A"
#  [7] "CXCL14"    "KRT14"     "LAMB3"     "CALD1"     "IGFBP7"    "COL17A1"
# [13] "CYR61"     "KRT5"      "PTRF"      "FHL2"      "LGALS1"    "SFN"
# [19] "TAGLN"     "CCL2"      "MT1E"      "TPM2"      "IGFBP2"    "ITGB1"
# [25] "MT1X"      "ITGB4"     "DCN"       "IFITM3"    "SPARC"     "AREG"
# [31] "TGFBI"     "TIMP1"     "FLNA"      "ITGA6"     "MYC"       "PHLDA1"
# [37] "SERPINF1"  "TNFRSF12A" "ACTN1"     "C1R"       "COL7A1"    "LAMC2"
# [43] "MMP10"     "MYL9"      "VIM"       "ACTA2"     "POSTN"     "CRYAB"
# [49] "COL18A1"   "PDLIM1"
#
# $Epithelial$`MP12 Respiration`
#  [1] "DEFB1"   "CKB"     "MPC1"    "CHCHD10" "IDH2"    "CYCS"    "KNG1"
#  [8] "UQCRH"   "ATP5G1"  "CD24"    "COX8A"   "FXYD2"   "NGFRAP1" "PRDX2"
# [15] "ATP5O"   "COX7B"   "MRPS6"   "NDUFB1"  "SLC25A4" "CYSTM1"  "GSTM3"
# [22] "ATP5G3"  "DUSP9"   "NUDT4"   "PRDX3"   "SLC25A5" "UMOD"    "ATP1B1"
# [29] "ATP5J"   "NDUFA1"  "ATP5B"   "ATP5H"   "COX6B1"  "HSPA2"   "TMEM52B"
# [36] "USMG5"   "ATP5C1"  "ATP5L"   "CBR1"    "ENO1"    "LDHB"    "NDUFS6"
# [43] "PEBP1"   "ALDOA"   "COX5A"   "COX5B"   "GSTP1"   "NDUFA5"  "S100A6"
# [50] "UCHL1"
#
# $Epithelial$`MP13 PDAC-related1`
#  [1] "FXYD2"    "OLFM4"    "PIGR"     "SERPINA1" "SERPING1" "CLDN10"
#  [7] "CLU"      "REG1A"    "SPP1"     "TFF1"     "DEFB1"    "SPINK1"
# [13] "TFF3"     "CD74"     "DUOX2"    "DUOXA2"   "GATM"     "HLA-DRB1"
# [19] "LCN2"     "MMP7"     "NNMT"     "TCN1"     "CFTR"     "GPX2"
# [25] "HLA-DRA"  "LGALS2"   "SLC3A1"   "TM4SF4"   "C3"       "CEACAM7"
# [31] "CRP"      "SLC4A4"   "SOD2"     "TFF2"     "AKR1B10"  "APCS"
# [37] "CRISP3"   "FOLR1"    "HLA-DRB5" "SERPINA5" "LYZ"      "CEACAM6"
# [43] "C8ORF4"   "PDZK1IP1" "MT1E"     "AKR1C3"   "CD81"     "IFITM3"
# [49] "HSD17B2"  "CA2"
#
# $Epithelial$`MP14 PDAC-related2`
#  [1] "C15ORF48" "CEACAM5"  "DUOX2"    "CEACAM6"  "F3"       "PSCA"
#  [7] "DHRS9"    "DUOXA2"   "LAMC2"    "S100P"    "TFF1"     "ANXA1"
# [13] "CTSE"     "KRT7"     "S100A4"   "CD55"     "ERO1L"    "ISG20"
# [19] "LMO7"     "MALL"     "PHGR1"    "PLAUR"    "SLPI"     "CLIC3"
# [25] "COL17A1"  "DPCR1"    "EPS8L1"   "GPRC5A"   "IFI6"     "ITGA2"
# [31] "KLK10"    "KRT19"    "MMP7"     "MUC1"     "PLAC8"    "SLC2A1"
# [37] "SLC6A14"  "TFF3"     "TRIM29"   "MUC5AC"   "PI3"      "IL32"
# [43] "PDZK1IP1" "PLAT"     "TIMP1"    "REG4"     "TSPAN1"   "APOL1"
# [49] "TACSTD2"  "CLDN23"
#
# $Epithelial$`MP15 Epi2`
#  [1] "WFDC2"   "ADIRF"   "S100A2"  "SLPI"    "ANXA2"   "CLDN10"  "ITM2C"
#  [8] "KRT7"    "LY6E"    "KRT19"   "LGALS3"  "MUC1"    "S100A11" "S100A6"
# [15] "SLC12A1" "SOD3"    "TIMP1"   "CXCL14"  "IFITM3"  "MGLL"    "MMP7"
# [22] "TACSTD2" "TM4SF1"  "TSPAN8"  "ANXA1"   "CA4"     "CD24"    "CLDN16"
# [29] "CLDN7"   "CLU"     "DEPTOR"  "IGFBP2"  "KRT17"   "MAL"     "PCSK1N"
# [36] "PERP"    "PTH1R"   "S100A10" "S100A14" "TSPAN1"  "S100A9"  "SOD2"
# [43] "IGFBP6"  "KNG1"    "PAPPA2"  "S100A4"  "ATP1B1"  "CD74"    "ACPP"
# [50] "HLA-B"
#
# $Epithelial$`MP16 Metabolism-Kidney2`
#  [1] "AQP2"      "HSD11B2"   "RALBP1"    "AQP3"      "FXYD4"     "KRT19"
#  [7] "ARG2"      "CTSH"      "GATA3"     "HMGCS2"    "TPM4"      "CDH16"
# [13] "CLDN8"     "WFDC2"     "BTG2"      "CA2"       "FOLR1"     "NDRG1"
# [19] "SCNN1G"    "ASAH1"     "ATP1B1"    "CLU"       "IER3"      "PTGER1"
# [25] "S100A2"    "SCPEP1"    "STC1"      "CALB1"     "CLDN7"     "EMX1"
# [31] "EPCAM"     "LHX1"      "MAL2"      "MAN1A1"    "PAPPA"     "PTGR1"
# [37] "RCAN1"     "RTN3"      "SELM"      "SLC8A1"    "SMIM22"    "TACSTD2"
# [43] "TMSB4X"    "TSPAN1"    "WNK1"      "WSB1"      "ST6GAL1"   "SCNN1B"
# [49] "GATA3-AS1" "ANXA2"
#
# $Epithelial$`MP17 EMT-like2`
#  [1] "IL32"      "MMP7"      "VIM"       "ANXA1"     "BIRC3"     "KRT7"
#  [7] "CCL2"      "TM4SF1"    "TPM1"      "TYMP"      "ANXA3"     "CALD1"
# ...
# [49] "GZMA"     "ANXA5"
#
# $CD4_T_cells$`MP10 Stress/HSP`
#  [1] "DNAJB1"   "FKBP4"    "DNAJA4"   "HSPA1B"   "HSPD1"    "HSPH1"
#  [7] "ZFAND2A"  "AHSA1"    "BAG3"     "CACYBP"   "DEDD2"    "HSP90AA1"
# [13] "HSPA1A"   "HSPA6"    "HSPE1"    "MRPL18"   "SERPINH1" "SQSTM1"
# [19] "CLK1"     "DNAJA1"   "DNAJB4"   "DOK2"     "DUSP1"    "HSPB1"
# [25] "ID2"      "PLIN2"    "REL"      "RGS2"     "TCP1"     "TSPYL2"
# [31] "JUN"      "PPP1R15A" "JUNB"     "HSP90AB1" "MYLIP"    "TRA2B"
# [37] "CHORDC1"  "SOCS3"    "BTG2"     "NUDC"     "ODC1"     "IRF1"
# [43] "PMAIP1"   "ANXA1"    "GADD45B"  "HBP1"     "FABP5"    "CCL20"
# [49] "NEU1"     "GEM"
#
#
# $CD8_T_cells
# $CD8_T_cells$`MP1 Cytotoxic`
#  [1] "GZMB"       "GZMH"       "PRF1"       "CCL4"       "GNLY"
#  [6] "GZMA"       "ALOX5AP"    "CCL4L2"     "KLRD1"      "CD63"
# [11] "HOPX"       "NKG7"       "CST7"       "GZMK"       "CCL3"
# [16] "APOBEC3G"   "IFNG"       "CXCR6"      "HLA-DRA"    "CMC1"
# [21] "HLA-DRB1"   "TIGIT"      "CXCL13"     "LAG3"       "CTSW"
# [26] "LGALS1"     "RGS1"       "HLA-DPA1"   "KLRB1"      "CD27"
# [31] "ITGB2"      "DUSP2"      "CTSD"       "DUSP4"      "HAVCR2"
# [36] "SAMSN1"     "ITM2C"      "TRGC2"      "ZNF683"     "HLA-DPB1"
# [41] "CAPG"       "KLRG1"      "RBPJ"       "AC092580.4" "ITM2A"
# [46] "CD7"        "CKLF"       "KLRC1"      "RGS2"       "ID2"
#
# $CD8_T_cells$`MP2 Cell_cycle`
#  [1] "STMN1"    "TUBB"     "TUBA1B"   "HMGB2"    "CKS1B"    "NUSAP1"
#  [7] "PCNA"     "TYMS"     "DUT"      "UBE2C"    "HMGN2"    "SMC4"
# [13] "TOP2A"    "HIST1H4C" "CDK1"     "MKI67"    "CENPF"    "KIAA0101"
# [19] "BIRC5"    "CKS2"     "PTTG1"    "ZWINT"    "MAD2L1"   "RANBP1"
# [25] "TK1"      "MCM7"     "CENPM"    "RRM2"     "SMC2"     "DNAJC9"
# [31] "TMPO"     "RPA3"     "TUBB4B"   "CDKN3"    "H2AFZ"    "UBE2T"
# [37] "AURKB"    "TMEM106C" "ASPM"     "NUDT1"    "KIF22"    "H2AFV"
# [43] "DEK"      "SIVA1"    "PCLAF"    "FABP5"    "CCNA2"    "DDX39A"
# [49] "TPX2"     "CARHSP1"
#
# $CD8_T_cells$`MP3 Memory/Naive1`
#  [1] "FOS"      "IL7R"     "DUSP1"    "GPR183"   "LTB"      "JUNB"
#  [7] "BTG2"     "FOSB"     "NFKBIA"   "DNAJB1"   "YPEL5"    "ZNF331"
# [13] "GZMK"     "CD69"     "ANXA1"    "RGCC"     "PPP1R15A" "LMNA"
# [19] "DUSP2"    "NR4A2"    "SLC2A3"   "TNFAIP3"  "CCR7"     "CD55"
# [25] "TXNIP"    "MYADM"    "ZFP36"    "JUN"      "BIRC3"    "DNAJA1"
# [31] "GADD45B"  "IER2"     "SNHG8"    "AREG"     "SELL"     "EIF3E"
# [37] "LEPROTL1" "TUBA4A"   "CREM"     "TMEM123"  "FAM177A1" "KLF6"
# [43] "PIK3IP1"  "PIK3R1"   "TOB1"     "TSC22D3"  "RGS2"     "TUBB4B"
# [49] "RGS1"     "CXCR4"
#
# $CD8_T_cells$`MP4 Interferon`
#  [1] "MX1"     "ISG15"   "IFI6"    "OASL"    "IFI44L"  "RSAD2"   "IFIT3"
#  [8] "OAS1"    "STAT1"   "PLSCR1"  "SAMD9L"  "TNFSF10" "IFI35"   "IFIT1"
# [15] "GBP1"    "HERC5"   "ISG20"   "USP18"   "IFI44"   "IFIT2"   "IRF7"
# [22] "NT5C3A"  "SAMD9"   "TRIM22"  "UBE2L6"  "EPSTI1"  "MX2"     "BST2"
# [29] "EIF2AK2" "OAS3"    "XAF1"    "CMPK2"   "MT2A"    "PPM1K"   "PARP14"
# [36] "OAS2"    "IFI16"   "LGALS9"  "NMI"     "PARP9"   "CD38"    "HELZ2"
# [43] "LAP3"    "LY6E"    "SP110"   "IFIH1"   "SAT1"    "TYMP"    "DDX58"
# [50] "ZBP1"
#
# $CD8_T_cells$`MP5 Unassigned1`
#  [1] "GIMAP7"   "GIMAP4"   "GZMK"     "ATRX"     "TXNIP"    "TRAF3IP3"
#  [7] "ARGLU1"   "KIAA1551" "KLRG1"    "MPHOSPH8" "BTN3A2"   "CMC1"
# [13] "PNISR"    "TBC1D10C" "DDX17"    "IKZF3"    "N4BP2L2"  "PPP1R18"
# [19] "SAMD3"    "AKAP9"    "CAP1"     "CD27"     "FYB"      "GIMAP1"
# [25] "IL7R"     "LCK"      "NKTR"     "PTP4A2"   "STK17A"   "TRGC2"
# [31] "APMAP"    "EVL"      "GCC2"     "ITGB2"    "LIMD2"    "MBNL1"
# [37] "PIK3IP1"  "PRPF38B"  "RNF213"   "SH2D1A"   "SYNE2"    "HLA-F"
# [43] "KLRB1"    "PLEK"     "UCP2"     "PRPF4B"   "POLR2J3"  "GPSM3"
# [49] "HLA-DRB1" "MBP"
#
# $CD8_T_cells$`MP6 Naive2`
#  [1] "SELL"      "TMEM123"   "CCR7"      "LTB"       "NOSIP"     "EIF3L"
#  [7] "IL7R"      "RSL1D1"    "TCF7"      "KLF2"      "LDHB"      "LEF1"
# [13] "PIK3IP1"   "MAL"       "SATB1"     "SNHG8"     "CD55"      "FAM65B"
# [19] "PLAC8"     "C6ORF48"   "FOXP1"     "LDLRAP1"   "PRKCQ-AS1" "TXK"
# [25] "AQP3"      "CD27"      "EIF2S3"    "EIF3E"     "FAIM3"     "NDFIP1"
# [31] "PPA1"      "ALKBH7"    "EIF3D"     "GIMAP1"    "MYC"       "NUCB2"
# [37] "PHB2"      "PRKCA"     "PRMT2"     "RASGRP2"   "RCAN3"     "SNHG7"
# [43] "SORL1"     "ST13"      "UXT"       "TXNIP"     "AIF1"      "ERP29"
# [49] "TRAT1"     "ATP5A1"
#
# $CD8_T_cells$`MP7 Glycolysis/MYC`
#  [1] "FABP5"    "NME1"     "C1QBP"    "RANBP1"   "EIF5A"    "NHP2"
#  [7] "PKM"      "TNFRSF9"  "CXCL13"   "SNRPE"    "ATP5G1"   "CCT2"
# [13] "ENO1"     "PGAM1"    "PRDX1"    "PRMT1"    "TNFRSF18" "XCL2"
# [19] "CRTAM"    "PPA1"     "RAN"      "VDAC1"    "XCL1"     "CCT5"
# [25] "CCT6A"    "HSP90B1"  "NDUFAB1"  "NFKBIA"   "PARK7"    "BIRC3"
# [31] "DCTPP1"   "DNPH1"    "EIF3I"    "FBL"      "GTF3C6"   "HSP90AB1"
# [37] "ILF2"     "PHB"      "SEC11C"   "TIMM13"   "TXNDC17"  "CALR"
# [43] "DUT"      "TNIP2"    "BATF"     "LSM5"     "BANF1"    "IMPDH2"
# [49] "NOP16"    "SNRPD1"
#
# $CD8_T_cells$`MP8 Chromatin`
#  [1] "NEAT1"        "SYNE2"        "MACF1"        "AHNAK"        "GOLGB1"
#  [6] "KMT2A"        "AKAP9"        "ANKRD11"      "NKTR"         "SMG1"
# [11] "SYNE1"        "ATRX"         "DDX17"        "GPRIN3"       "SMCHD1"
# [16] "UTRN"         "ZNF292"       "AKNA"         "ARGLU1"       "CHD2"
# [21] "ITGA4"        "PCSK7"        "PHF3"         "ROCK1"        "RORA"
# [26] "ATF7IP"       "ATM"          "BPTF"         "CBLB"         "DDX6"
# [31] "DYNC1H1"      "FYN"          "LINC-PINT"    "MT-ND6"       "MYH9"
# [36] "NUFIP2"       "OGA"          "PDE3B"        "RESF1"        "RP11-138A9.1"
# [41] "SETX"         "XIST"         "SLFN5"        "EML4"         "GCC2"
# [46] "IKZF3"        "BDP1"         "RASGRP1"      "GOLGA4"       "CEP350"
#
# $CD8_T_cells$`MP9 Unassigned2`
#  [1] "COTL1"    "PPP1CA"   "PSME2"    "ARPC1B"   "FKBP1A"   "LGALS1"
#  [7] "CAP1"     "ENO1"     "MT2A"     "TPI1"     "TUBB"     "PARK7"
# [13] "S100A4"   "APOBEC3G" "ARPC5"    "CAPZB"    "CORO1A"   "EMP3"
# [19] "PKM"      "PPP1R18"  "ANXA5"    "ARPC4"    "ATP5G3"   "CALM3"
# [25] "CLIC1"    "GZMA"     "GZMH"     "LSP1"     "PGAM1"    "PSME1"
# [31] "S100A11"  "STMN1"    "TXN"      "ACTB"     "BLOC1S1"  "C12ORF75"
# [37] "CAPG"     "CKLF"     "IL32"     "MYL12A"   "PSMA7"    "RAC2"
# [43] "SLC25A5"  "SNRPE"    "TBC1D10C" "CD52"     "SH3BGRL3" "ITM2C"
# [49] "PFN1"     "LY6E"
#
# $CD8_T_cells$`MP10 Heat_shock`
#  [1] "HSPA1B"   "HSPH1"    "HSPA1A"   "HSPA6"    "HSPB1"    "ZFAND2A"
#  [7] "CACYBP"   "HSPD1"    "AHSA1"    "DNAJA1"   "HSPE1"    "MRPL18"
# [13] "PPP1R15A" "SERPINH1" "TSPYL2"   "BAG3"     "DNAJB1"   "HSP90AA1"
# [19] "IFNG"     "DEDD2"    "FKBP4"    "HSP90AB1" "NEU1"     "RGS2"
# [25] "CHORDC1"  "DNAJA4"   "DOK2"     "GADD45B"  "NUDC"     "BATF"
# [31] "CLK1"     "NR4A1"    "NR4A2"    "PMAIP1"   "RHOB"     "SQSTM1"
# [37] "TAF7"     "TCP1"     "TNFSF14"  "JUN"      "DUSP1"    "CCL3"
# [43] "CCL4L2"   "STIP1"    "FOSB"     "DUSP4"    "HSPA4"    "ANKRD37"
# [49] "TXNIP"    "PTGES3"
#
# $CD8_T_cells$`MP11 Naive3`
#  [1] "KLRB1"    "LTB"      "RORA"     "IL7R"     "NCR3"     "SPOCK2"
#  [7] "TMIGD2"   "CCR6"     "CTSH"     "FKBP11"   "CCL20"    "HPGD"
# [13] "IL4I1"    "LST1"     "ALOX5AP"  "AQP3"     "CEBPD"    "CXCR6"
# [19] "GNA15"    "GPR171"   "GPR65"    "JAML"     "ODF2L"    "PERP"
# [25] "RBMS1"    "TANK"     "TNFRSF25" "FURIN"    "IFI44"    "IFNGR1"
# [31] "LGALS3"   "PHACTR2"  "RBPJ"     "ANKRD28"  "NINJ1"    "ERN1"
# [37] "TNFSF13B" "NFKBIA"   "TTC39C"   "CELF2"    "HOPX"     "MAF"
# [43] "GNLY"     "SATB1"    "CERK"     "GPX1"     "PFKFB3"   "TNFRSF18"
# [49] "PRDM1"    "SNX9"
#
# $CD8_T_cells$`MP12 Dysfunction`
#  [1] "TNFRSF18" "ARID5B"   "BATF"     "NR3C1"    "TIGIT"    "CXCL13"
#  [7] "PKM"      "TNFRSF4"  "UCP2"     "C9ORF16"  "CD27"     "DNPH1"
# [13] "BIRC3"    "CTLA4"    "LTB"      "PARK7"    "PMAIP1"   "TNFRSF9"
# [19] "CNIH1"    "DUSP4"    "GBP2"     "IL6ST"    "ITM2A"    "NFKBIA"
# [25] "PEBP1"    "PGAM1"    "SPOCK2"   "TBC1D4"   "CD82"     "CORO1B"
# [31] "GEM"      "ICA1"     "IL7R"     "KLRB1"    "MAF"      "MAGEH1"
# [37] "RBPJ"     "SNX9"     "STAT3"    "AP2M1"    "CCR7"     "CHN1"
# [43] "CRTAM"    "EIF3I"    "FKBP1A"   "FKBP5"    "GPX4"     "HSPB1"
# [49] "ICOS"     "IGFLR1"
#
#
# $B_cells
# $B_cells$`MP1 Plasma`
#  [1] "DERL3"    "MZB1"     "JCHAIN"   "PRDX4"    "XBP1"     "SEC11C"
#  [7] "FKBP11"   "FKBP2"    "IGHG3"    "IGHG1"    "ITM2C"    "IGKC"
# [13] "IGLC2"    "IGLC3"    "HSP90B1"  "IGHA1"    "SSR4"     "IGHG4"
# [19] "NUCB2"    "SPCS3"    "MANF"     "SSR3"     "SDF2L1"   "MYDGF"
# [25] "IGHG2"    "PPIB"     "SPCS1"    "IGHA2"    "HSPA5"    "CD63"
# [31] "LMAN1"    "IGHGP"    "PDIA4"    "HERPUD1"  "DNAJB9"   "ERLEC1"
# [37] "RPN2"     "SEC61B"   "PDIA6"    "SPCS2"    "TMEM258"  "CRELD2"
# [43] "RABAC1"   "SDC1"     "KRTCAP2"  "PIM2"     "TNFRSF17" "TMEM59"
# [49] "VIMP"     "P4HB"
#
# $B_cells$`MP2 MHC-II`
#  [1] "HLA-DPB1" "HLA-DRA"  "HLA-DRB1" "LAPTM5"   "HLA-DPA1" "LTB"
#  [7] "HLA-DQB1" "HLA-DQA1" "MS4A1"    "CD52"     "CD37"     "COTL1"
# [13] "CORO1A"   "BANK1"    "CD69"     "HLA-DMB"  "CXCR4"    "SMIM14"
# [19] "CD53"     "LIMD2"    "ARHGDIB"  "HLA-DMA"  "BTG1"     "CD48"
# [25] "SELL"     "TXNIP"    "VPREB3"   "CD79B"    "CD83"     "ACTB"
# [31] "HLA-DRB5" "ZFAS1"    "PTPRC"    "ACTG1"    "CD74"     "MYL12A"
# [37] "REL"      "ARPC1B"   "SH3BGRL3" "NAP1L1"   "RAC2"     "STK17A"
# [43] "GPSM3"    "LY86"     "PFN1"     "GPR183"   "IFITM2"   "JUNB"
# [49] "LCP1"     "TMSB4X"
#
# $B_cells$`MP3 Cell-cycle`
#  [1] "HMGB2"    "STMN1"    "TUBA1B"   "TUBB"     "HMGN2"    "PTTG1"
#  [7] "DUT"      "NUSAP1"   "H2AFZ"    "PCNA"     "HMGA1"    "PCLAF"
# [13] "CKS1B"    "RANBP1"   "SMC4"     "HMGB1"    "TK1"      "MKI67"
# [19] "LDHA"     "TYMS"     "TOP2A"    "H4C3"     "HIST1H4C" "RAN"
# [25] "TCL1A"    "UBE2C"    "ENO1"     "H2AZ1"    "CENPM"    "SLC25A5"
# [31] "MCM7"     "SNRPD1"   "AURKB"    "CDK1"     "DEK"      "PKM"
# [37] "TUBB4B"   "ANP32B"   "ANP32E"   "BIRC5"    "CDKN3"    "CKS2"
# [43] "H2AFV"    "KPNA2"    "LRMP"     "RRM2"     "ZWINT"    "GAPDH"
# [49] "SNRPF"    "H2AZ2"
#
# $B_cells$`MP4 Stress`
#  [1] "CD69"      "FOS"       "JUN"       "CD83"      "NR4A2"     "FOSB"
#  [7] "IGHD"      "IGHM"      "DUSP1"     "FCER2"     "FOXP1"     "TCL1A"
# [13] "ZNF331"    "ZFP36"     "GPR183"    "CD55"      "FCMR"      "JUNB"
# [19] "RGS2"      "YPEL5"     "CCR7"      "LINC00926" "RHOH"      "IER2"
# [25] "SELL"      "SLC2A3"    "BIRC3"     "BTG2"      "LY9"       "IL4R"
# [31] "ZFP36L2"   "CLEC2D"    "HVCN1"     "PPP1R15A"  "SNX2"      "AREG"
# [37] "DUSP2"     "GADD45B"   "KLF2"      "KLF6"      "ADAM28"    "CD72"
# [43] "NFKBIA"    "VPREB3"    "CD22"      "CREM"      "NR4A1"     "PHACTR1"
# [49] "TSPAN13"   "VPS37B"
#
# $B_cells$`MP5 B-cells1`
#  [1] "CRIP1"     "TNFRSF13B" "CAPG"      "ITGB1"     "CD99"      "S100A4"
#  [7] "ACP5"      "CD82"      "CLECL1"    "HCST"      "SCIMP"     "ANXA2"
# [13] "COTL1"     "CTSH"      "VIM"       "CD27"      "LGALS1"    "PLP2"
# [19] "CCDC50"    "FCRL5"     "NEAT1"     "S100A11"   "S100A10"   "UBE2N"
# [25] "AIM2"      "EMP3"      "S100A6"    "ARPC1B"    "LSP1"      "PTPN1"
# [31] "RGS1"      "EVI2B"     "GRN"       "IFI30"     "RGCC"      "SRGN"
# [37] "SUB1"      "CAPZB"     "ENTPD1"    "GPR183"    "IGHA1"     "CD86"
# [43] "GSTK1"     "HOPX"      "IGFLR1"    "PLEK"      "BLK"       "BHLHE41"
# [49] "ISCU"      "CXCR3"
#
# $B_cells$`MP6 Metabolism/MYC`
#  [1] "PSME2"    "ENO1"     "LDHA"     "NME1"     "RANBP1"   "TUBB"
#  [7] "C1QBP"    "EIF5A"    "NHP2"     "PKM"      "PRDX1"    "RAN"
# [13] "FABP5"    "SNRPD1"   "VDAC1"    "HSPD1"    "PPA1"     "SNRPE"
# [19] "PA2G4"    "RPL22L1"  "SNRPF"    "TUBA1B"   "CCT3"     "DDX21"
# [25] "EIF4A1"   "HMGA1"    "IMPDH2"   "LDHB"     "PRMT1"    "PSMB3"
# [31] "CALR"     "HSP90AB1" "HSPE1"    "NME2"     "PGAM1"    "TPI1"
# [37] "TXN"      "ABRACL"   "ATP5G1"   "NDUFAB1"  "PSMA4"    "SYNGR2"
# [43] "TIMM13"   "APRT"     "CCT6A"    "CD83"     "ERH"      "MIF"
# [49] "PRELID1"  "HNRNPAB"
#
# $B_cells$`MP7 B-cells2`
#  [1] "LRMP"     "NEIL1"    "TCL1A"    "MARCKSL1" "RGS13"    "RFTN1"
#  [7] "BASP1"    "HMCES"    "BCL7A"    "LCP1"     "LPP"      "UBE2J1"
# [13] "PRDX6"    "SYNE2"    "CD22"     "FAM3C"    "HOPX"     "CCDC144A"
# [19] "KLHL6"    "PARP1"    "PRPSAP2"  "ABRACL"   "CD40"     "CD79B"
# [25] "DBI"      "GCHFR"    "LAT2"     "LMO2"     "POU2AF1"  "RGS1"
# [31] "TMEM123"  "BCAS4"    "DAAM1"    "GGA2"     "HMGA1"    "HMGN1"
# [37] "LCK"      "MTF2"     "P2RX5"    "RNGTT"    "STAG3"    "UCP2"
# [43] "JCHAIN"   "SERPINA9" "CCDC88A"  "SUSD3"    "GRHPR"    "ACTG1"
# [49] "PPP2CA"   "CPNE3"
#
# $B_cells$`MP8 Interferon`
#  [1] "MX1"      "PLSCR1"   "SAMD9L"   "GBP1"     "GBP4"     "IFI6"
#  [7] "IFIT2"    "IFIT3"    "ISG15"    "MX2"      "OAS1"     "PARP9"
# [13] "TNFSF10"  "CMPK2"    "IFI35"    "IFIT1"    "IRF7"     "PARP14"
# [19] "SAMD9"    "STAT1"    "TRIM22"   "UBE2L6"   "USP18"    "XAF1"
# [25] "APOL6"    "BST2"     "HERC5"    "IFI44"    "IFI44L"   "NT5C3A"
# [31] "OAS3"     "RABGAP1L" "RNF213"   "RSAD2"    "CHST12"   "EIF2AK2"
# [37] "LY6E"     "MNDA"     "NMI"      "IFITM1"   "ISG20"    "LAP3"
# [43] "MT2A"     "OAS2"     "PPM1K"    "SLFN5"    "SOCS1"    "EPSTI1"
# [49] "TAP1"     "DYNLT1"
#
# $B_cells$`MP9 Progenitor`
#  [1] "SOX4"     "VPREB1"   "CD9"      "IGLL1"    "CD24"     "MZB1"
#  [7] "SNHG7"    "STMN1"    "NEIL1"    "VPREB3"   "CD38"     "PCDH9"
# [13] "CCDC191"  "CMTM7"    "DNTT"     "GAPDH"    "H1FX"     "MME"
# [19] "NSMCE1"   "SSBP2"    "TCL1A"    "TOP2B"    "YBX3"     "ARPP21"
# [25] "BACH2"    "BCL7A"    "CDC25B"   "EBF1"     "GLRX"     "HMGB2"
# [31] "MLXIP"    "MT1X"     "NIBAN3"   "RCSD1"    "S1PR4"    "TKT"
# [37] "VDAC1"    "LDLRAD4"  "CCDC112"  "CD99"     "RGS2"     "ITM2C"
# [43] "TRAM1"    "IGLL5"    "UBE2J1"   "PTPRE"    "CD72"     "TP53INP1"
# [49] "TCF4"     "TMEM243"
#
# $B_cells$`MP10 B-cells3`
#  [1] "NKTR"      "ARGLU1"    "ATM"       "RBM6"      "ARID1B"    "ATRX"
#  [7] "BDP1"      "BPTF"      "MDM4"      "NEAT1"     "PARP14"    "SEL1L3"
# [13] "SYNE2"     "ZNF292"    "ASH1L"     "ATF7IP"    "BIRC3"     "CD22"
# [19] "CLEC2D"    "CTNNB1"    "FTX"       "HNRNPH1"   "ITSN2"     "KMT2A"
# [25] "LNPEP"     "MBNL1"     "PCSK7"     "PSMA3-AS1" "RSRP1"     "SFPQ"
# [31] "STX7"      "TNRC6B"    "XIST"      "TTN"       "C1ORF56"   "RASGEF1B"
# [37] "ADAM19"    "B4GALT1"   "FAM214A"   "PRDM2"     "PPP3CA"    "GOLGB1"
# [43] "CDC42SE1"  "TUT4"      "IKZF3"     "CDK13"     "CCNL1"     "OGA"
# [49] "SET"       "ANKRD11"
#
# $B_cells$`MP11 Respiration`
#  [1] "PPIB"   "H2AFZ"  "JCHAIN" "ATP5G3" "COX7B"  "HMGB1"  "RAN"    "CYCS"
#  [9] "HSPE1"  "LGALS1" "PDIA6"  "PPIA"   "SNRPD2" "SNRPG"  "ATP5I"  "ATP5J2"
# [17] "CHCHD2" "COX6C"  "DBI"    "GLRX"   "IGHA1"  "LSM3"   "NDUFS5" "NOP10"
# [25] "NPM1"   "POLR2L" "PRDX1"  "PSME2"  "SEC61B" "SSR3"   "COX6B1" "POMP"
# [33] "ATP5O"  "COX7A2" "PTMA"   "CLIC1"  "BTF3"   "SSR2"   "ANXA2"  "TMSB10"
# [41] "PPA1"   "TMA7"   "NME1"   "TXN"    "ATP5J"  "UQCRH"  "NDUFB3" "SUB1"
# [49] "RPS7"   "HN1"
#
# $B_cells$`MP12 HSP/Stress`
#  [1] "CACYBP"   "HSPA1B"   "CD69"     "DNAJB1"   "HSPB1"    "NR4A1"
#  [7] "DEDD2"    "FKBP4"    "HSPA1A"   "HSPA6"    "HSPD1"    "CCR7"
# [13] "CHORDC1"  "DNAJA1"   "EGR1"     "EGR3"     "HSP90AA1" "HSP90AB1"
# [19] "HSPE1"    "HSPH1"    "JUN"      "KLF6"     "MRPL18"   "MYC"
# [25] "NFKBID"   "SLBP"     "STIP1"    "TAF7"     "UBC"      "ZFAND2A"
# [31] "PMAIP1"   "CCL4"     "UBB"      "NFKBIA"   "NUDC"     "SLC5A3"
# [37] "AHSA1"    "IGHA1"    "ANKRD12"  "IER2"     "SMIM14"   "HSPA8"
# [43] "DUSP2"    "FOS"      "MIR155HG" "BCL2A1"   "CD83"     "DDX5"
# [49] "DNAJB4"   "IGHG1"

# %%
library(jsonlite)
# Out:
# Warning message:
# “package ‘jsonlite’ was built under R version 4.1.2”
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %%
write_json(MP_list, '../../../Data/Misc/Gavish_2023_Nat/MP_list.json')

# %%
MP_list_T
# Out:
# $`CD4_MP1 T_reg`
#  [1] "IL2RA"       "TNFRSF18"    "TNFRSF4"     "TIGIT"       "BATF"
#  [6] "CD27"        "CARD16"      "FOXP3"       "CTLA4"       "TNFRSF1B"
# [11] "PMAIP1"      "CTSC"        "LAIR2"       "TNFRSF9"     "GLRX"
# [16] "DNPH1"       "TBC1D4"      "DUSP4"       "GBP2"        "ICOS"
# [21] "MAGEH1"      "TYMP"        "CXCR6"       "CD7"         "CST7"
# [26] "SAT1"        "GADD45A"     "IL1R2"       "GBP5"        "UGP2"
# [31] "AC133644.2"  "UCP2"        "PIM2"        "LAYN"        "PKM"
# [36] "RTKN2"       "ACP5"        "MIR4435-2HG" "ARID5B"      "PHLDA1"
# [41] "IL2RB"       "SYNGR2"      "LTB"         "CASP1"       "HLA-DRB1"
# [46] "IFI6"        "NAMPT"       "CORO1B"      "LGALS1"      "BTG3"
#
# $`CD4_MP2 Naive1`
#  [1] "ANXA1"    "FOS"      "CD69"     "CCR7"     "GPR183"   "KLRB1"
#  [7] "IL7R"     "GIMAP7"   "CXCR4"    "SLC2A3"   "BTG2"     "CD55"
# [13] "YPEL5"    "ZFP36L2"  "NR4A2"    "GIMAP4"   "PTGER4"   "ALOX5AP"
# [19] "TRAT1"    "DUSP1"    "FOSB"     "CCL5"     "DNAJB1"   "TXNIP"
# [25] "SELL"     "KLF2"     "GPR171"   "GZMA"     "PLAC8"    "CD48"
# [31] "JUN"      "TCF7"     "PPP2R5C"  "AREG"     "RGCC"     "FOXP1"
# [37] "FAM177A1" "NOSIP"    "RARRES3"  "LMNA"     "SNHG8"    "ZNF331"
# [43] "DUSP2"    "IER2"     "JUNB"     "SOCS3"    "TMEM123"  "TOB1"
# [49] "ZFP36"    "LEPROTL1"
#
# $`CD4_MP3 Cell_cycle`
#  [1] "STMN1"    "TUBA1B"   "TUBB"     "NUSAP1"   "HMGB2"    "CKS1B"
#  [7] "TYMS"     "UBE2C"    "MKI67"    "TOP2A"    "PCNA"     "TK1"
# [13] "ZWINT"    "BIRC5"    "CDK1"     "HIST1H4C" "DUT"      "CENPF"
# [19] "HMGN2"    "MAD2L1"   "CENPM"    "SMC4"     "SMC2"     "RRM2"
# [25] "MCM7"     "CDKN3"    "PTTG1"    "KIAA0101" "CKS2"     "NUDT1"
# [31] "TMEM106C" "UBE2T"    "ASF1B"    "DNAJC9"   "H2AFZ"    "CENPW"
# [37] "ASPM"     "DTYMK"    "FEN1"     "PCLAF"    "TPX2"     "TUBB4B"
# [43] "AURKB"    "TMPO"     "TUBA1C"   "DDX39A"   "KPNA2"    "PHF19"
# [49] "KIF22"    "CCNA2"
#
# $`CD4_MP4 Cytotoxic`
#  [1] "CCL5"       "GZMA"       "CCL4"       "ID2"        "CST7"
#  [6] "GZMB"       "GZMH"       "ALOX5AP"    "NKG7"       "APOBEC3G"
# [11] "HLA-DRB1"   "IFNG"       "GZMK"       "PRF1"       "CXCR6"
# [16] "LGALS1"     "RBPJ"       "GNLY"       "KLRB1"      "HOPX"
# [21] "HLA-DPB1"   "AC092580.4" "CTSD"       "CXCL13"     "CKLF"
# [26] "HLA-DPA1"   "CLEC2B"     "CTSW"       "HLA-DRA"    "CD99"
# [31] "ANXA1"      "PDCD1"      "CCL4L2"     "C12ORF75"   "CD6"
# [36] "COTL1"      "LINC00152"  "ANXA2"      "DUSP4"      "GZMM"
# [41] "ANKRD28"    "CCL3"       "CD63"       "CD96"       "LAG3"
# [46] "ITGB2"      "PLIN2"      "ZEB2"       "JUN"        "BHLHE40"
#
# $`CD4_MP5 Dysfunction`
#  [1] "NR3C1"    "CXCL13"   "FKBP5"    "ITM2A"    "RNF19A"   "ICA1"
#  [7] "SH2D1A"   "TIGIT"    "PPP1CC"   "IL6ST"    "LIMS1"    "NMB"
# [13] "TSHZ2"    "KLRB1"    "PDCD1"    "TOX2"     "MAGEH1"   "SMCO4"
# [19] "ALOX5AP"  "FABP5"    "MAF"      "RBPJ"     "NAP1L4"   "SLA"
# [25] "TOX"      "BTLA"     "CD200"    "CPM"      "RGS2"     "SESN1"
# [31] "CD84"     "PASK"     "TBC1D4"   "THADA"    "AKAP13"   "C9ORF16"
# [37] "CD40LG"   "CHI3L2"   "CHN1"     "DUSP4"    "YWHAQ"    "CORO1B"
# [43] "COTL1"    "TCF7"     "TNFRSF18" "PCAT29"   "PVALB"    "SFXN1"
# [49] "NUDT16"   "AHI1"
#
# $`CD4_MP6 Interferon`
#  [1] "ISG15"       "IFIT1"       "MX1"         "RSAD2"       "IFI44L"
#  [6] "CMPK2"       "HERC5"       "IFIT2"       "IFIT3"       "IRF7"
# [11] "MX2"         "OAS1"        "OASL"        "EIF2AK2"     "OAS2"
# [16] "SAMD9"       "USP18"       "GBP1"        "IFI6"        "ISG20"
# [21] "PPM1K"       "SAMD9L"      "STAT1"       "TRIM22"      "IFI44"
# [26] "MT2A"        "NT5C3A"      "OAS3"        "IFI35"       "TNFSF10"
# [31] "UBE2L6"      "XAF1"        "EPSTI1"      "LY6E"        "PARP9"
# [36] "PLSCR1"      "ZBP1"        "HELZ2"       "PARP14"      "RBCK1"
# [41] "SHFL"        "SP110"       "STAT2"       "DDX58"       "HSH2D"
# [46] "PALM2-AKAP2" "PARP10"      "RTP4"        "CHST12"      "LAP3"
#
# $`CD4_MP7 Glycolysis/MYC`
#  [1] "NME1"     "RANBP1"   "CCT5"     "EIF5A"    "FABP5"    "C1QBP"
#  [7] "NHP2"     "PDCD5"    "PPA1"     "PRMT1"    "SRM"      "TNFRSF4"
# [13] "IL2RA"    "SMS"      "ATP5G1"   "DUT"      "PKM"      "TIMM13"
# [19] "TNFRSF18" "TXNDC17"  "DCTPP1"   "DDX21"    "HSPD1"    "MRPL12"
# [25] "NOLC1"    "PGAM1"    "PHB"      "SNRPD1"   "TUBB"     "EBNA1BP2"
# [31] "IL1R2"    "PAICS"    "PCNA"     "PRDX1"    "SNRPE"    "CCND2"
# [37] "CCT2"     "CCT3"     "EEF1E1"   "LSM2"     "LSM5"     "MRPL14"
# [43] "NDUFAB1"  "NDUFB3"   "TNFRSF9"  "TXN"      "SSBP1"    "DNPH1"
# [49] "TOMM40"   "EIF5B"
#
# $`CD4_MP8 Naive2`
#  [1] "CCR7"         "LEF1"         "MAL"          "SELL"         "KLF2"
#  [6] "MYC"          "NOSIP"        "C6ORF48"      "PLAC8"        "PRKCQ-AS1"
# [11] "SNORA76"      "TCF7"         "TRAT1"        "APEX1"        "C1ORF162"
# [16] "GIMAP5"       "LINC00861"    "PRKCA"        "RSL1D1"       "CCDC109B"
# [21] "EPB41L4A-AS1" "FAM65B"       "GIMAP1"       "GIMAP2"       "ICAM2"
# [26] "ITGB1"        "KLRB1"        "LPAR6"        "RASGRP2"      "SATB1"
# [31] "SH3BP5"       "ST13"         "TIMP1"        "TMEM243"      "TRABD2A"
# [36] "FHIT"         "CD27"         "TAGAP"        "ALKBH7"       "FOXP1"
# [41] "SNHG7"        "RIC3"         "IL6ST"        "TSHZ2"        "SMDT1"
# [46] "EIF2S3"       "PIM2"         "PRMT2"        "CREBRF"       "SORL1"
#
# $`CD4_MP9 Unassigned`
#  [1] "ARPC4"    "CKLF"     "LGALS1"   "ALOX5AP"  "CAP1"     "LTB"
#  [7] "S100A4"   "CORO1B"   "EMP3"     "LY6E"     "PKM"      "ANXA6"
# [13] "ARPC1B"   "ARPC5"    "C9ORF16"  "DBI"      "LSP1"     "PRELID1"
# [19] "TRAPPC1"  "ANXA2"    "APRT"     "ATP5J"    "CLIC1"    "COTL1"
# [25] "ISG15"    "KLRB1"    "LCP1"     "LGALS3"   "MT2A"     "PARK7"
# [31] "PSME2"    "S100A10"  "SEC61G"   "UCP2"     "BRK1"     "ID2"
# [37] "COPS9"    "PPP1CA"   "CORO1A"   "TXN"      "TSPO"     "IFI27L2"
# [43] "LCK"      "NEDD8"    "PRDX1"    "DAD1"     "APOBEC3G" "YWHAQ"
# [49] "GZMA"     "ANXA5"
#
# $`CD4_MP10 Stress/HSP`
#  [1] "DNAJB1"   "FKBP4"    "DNAJA4"   "HSPA1B"   "HSPD1"    "HSPH1"
#  [7] "ZFAND2A"  "AHSA1"    "BAG3"     "CACYBP"   "DEDD2"    "HSP90AA1"
# [13] "HSPA1A"   "HSPA6"    "HSPE1"    "MRPL18"   "SERPINH1" "SQSTM1"
# [19] "CLK1"     "DNAJA1"   "DNAJB4"   "DOK2"     "DUSP1"    "HSPB1"
# [25] "ID2"      "PLIN2"    "REL"      "RGS2"     "TCP1"     "TSPYL2"
# [31] "JUN"      "PPP1R15A" "JUNB"     "HSP90AB1" "MYLIP"    "TRA2B"
# [37] "CHORDC1"  "SOCS3"    "BTG2"     "NUDC"     "ODC1"     "IRF1"
# [43] "PMAIP1"   "ANXA1"    "GADD45B"  "HBP1"     "FABP5"    "CCL20"
# [49] "NEU1"     "GEM"
#
# $`CD8_MP1 Cytotoxic`
#  [1] "GZMB"       "GZMH"       "PRF1"       "CCL4"       "GNLY"
#  [6] "GZMA"       "ALOX5AP"    "CCL4L2"     "KLRD1"      "CD63"
# [11] "HOPX"       "NKG7"       "CST7"       "GZMK"       "CCL3"
# [16] "APOBEC3G"   "IFNG"       "CXCR6"      "HLA-DRA"    "CMC1"
# [21] "HLA-DRB1"   "TIGIT"      "CXCL13"     "LAG3"       "CTSW"
# [26] "LGALS1"     "RGS1"       "HLA-DPA1"   "KLRB1"      "CD27"
# [31] "ITGB2"      "DUSP2"      "CTSD"       "DUSP4"      "HAVCR2"
# [36] "SAMSN1"     "ITM2C"      "TRGC2"      "ZNF683"     "HLA-DPB1"
# [41] "CAPG"       "KLRG1"      "RBPJ"       "AC092580.4" "ITM2A"
# [46] "CD7"        "CKLF"       "KLRC1"      "RGS2"       "ID2"
#
# $`CD8_MP2 Cell_cycle`
#  [1] "STMN1"    "TUBB"     "TUBA1B"   "HMGB2"    "CKS1B"    "NUSAP1"
#  [7] "PCNA"     "TYMS"     "DUT"      "UBE2C"    "HMGN2"    "SMC4"
# [13] "TOP2A"    "HIST1H4C" "CDK1"     "MKI67"    "CENPF"    "KIAA0101"
# [19] "BIRC5"    "CKS2"     "PTTG1"    "ZWINT"    "MAD2L1"   "RANBP1"
# [25] "TK1"      "MCM7"     "CENPM"    "RRM2"     "SMC2"     "DNAJC9"
# [31] "TMPO"     "RPA3"     "TUBB4B"   "CDKN3"    "H2AFZ"    "UBE2T"
# [37] "AURKB"    "TMEM106C" "ASPM"     "NUDT1"    "KIF22"    "H2AFV"
# [43] "DEK"      "SIVA1"    "PCLAF"    "FABP5"    "CCNA2"    "DDX39A"
# [49] "TPX2"     "CARHSP1"
#
# $`CD8_MP3 Memory/Naive1`
#  [1] "FOS"      "IL7R"     "DUSP1"    "GPR183"   "LTB"      "JUNB"
#  [7] "BTG2"     "FOSB"     "NFKBIA"   "DNAJB1"   "YPEL5"    "ZNF331"
# [13] "GZMK"     "CD69"     "ANXA1"    "RGCC"     "PPP1R15A" "LMNA"
# [19] "DUSP2"    "NR4A2"    "SLC2A3"   "TNFAIP3"  "CCR7"     "CD55"
# [25] "TXNIP"    "MYADM"    "ZFP36"    "JUN"      "BIRC3"    "DNAJA1"
# [31] "GADD45B"  "IER2"     "SNHG8"    "AREG"     "SELL"     "EIF3E"
# [37] "LEPROTL1" "TUBA4A"   "CREM"     "TMEM123"  "FAM177A1" "KLF6"
# [43] "PIK3IP1"  "PIK3R1"   "TOB1"     "TSC22D3"  "RGS2"     "TUBB4B"
# [49] "RGS1"     "CXCR4"
#
# $`CD8_MP4 Interferon`
#  [1] "MX1"     "ISG15"   "IFI6"    "OASL"    "IFI44L"  "RSAD2"   "IFIT3"
#  [8] "OAS1"    "STAT1"   "PLSCR1"  "SAMD9L"  "TNFSF10" "IFI35"   "IFIT1"
# [15] "GBP1"    "HERC5"   "ISG20"   "USP18"   "IFI44"   "IFIT2"   "IRF7"
# [22] "NT5C3A"  "SAMD9"   "TRIM22"  "UBE2L6"  "EPSTI1"  "MX2"     "BST2"
# [29] "EIF2AK2" "OAS3"    "XAF1"    "CMPK2"   "MT2A"    "PPM1K"   "PARP14"
# [36] "OAS2"    "IFI16"   "LGALS9"  "NMI"     "PARP9"   "CD38"    "HELZ2"
# [43] "LAP3"    "LY6E"    "SP110"   "IFIH1"   "SAT1"    "TYMP"    "DDX58"
# [50] "ZBP1"
#
# $`CD8_MP5 Unassigned1`
#  [1] "GIMAP7"   "GIMAP4"   "GZMK"     "ATRX"     "TXNIP"    "TRAF3IP3"
#  [7] "ARGLU1"   "KIAA1551" "KLRG1"    "MPHOSPH8" "BTN3A2"   "CMC1"
# [13] "PNISR"    "TBC1D10C" "DDX17"    "IKZF3"    "N4BP2L2"  "PPP1R18"
# [19] "SAMD3"    "AKAP9"    "CAP1"     "CD27"     "FYB"      "GIMAP1"
# [25] "IL7R"     "LCK"      "NKTR"     "PTP4A2"   "STK17A"   "TRGC2"
# [31] "APMAP"    "EVL"      "GCC2"     "ITGB2"    "LIMD2"    "MBNL1"
# [37] "PIK3IP1"  "PRPF38B"  "RNF213"   "SH2D1A"   "SYNE2"    "HLA-F"
# [43] "KLRB1"    "PLEK"     "UCP2"     "PRPF4B"   "POLR2J3"  "GPSM3"
# [49] "HLA-DRB1" "MBP"
#
# $`CD8_MP6 Naive2`
#  [1] "SELL"      "TMEM123"   "CCR7"      "LTB"       "NOSIP"     "EIF3L"
#  [7] "IL7R"      "RSL1D1"    "TCF7"      "KLF2"      "LDHB"      "LEF1"
# [13] "PIK3IP1"   "MAL"       "SATB1"     "SNHG8"     "CD55"      "FAM65B"
# [19] "PLAC8"     "C6ORF48"   "FOXP1"     "LDLRAP1"   "PRKCQ-AS1" "TXK"
# [25] "AQP3"      "CD27"      "EIF2S3"    "EIF3E"     "FAIM3"     "NDFIP1"
# [31] "PPA1"      "ALKBH7"    "EIF3D"     "GIMAP1"    "MYC"       "NUCB2"
# [37] "PHB2"      "PRKCA"     "PRMT2"     "RASGRP2"   "RCAN3"     "SNHG7"
# [43] "SORL1"     "ST13"      "UXT"       "TXNIP"     "AIF1"      "ERP29"
# [49] "TRAT1"     "ATP5A1"
#
# $`CD8_MP7 Glycolysis/MYC`
#  [1] "FABP5"    "NME1"     "C1QBP"    "RANBP1"   "EIF5A"    "NHP2"
#  [7] "PKM"      "TNFRSF9"  "CXCL13"   "SNRPE"    "ATP5G1"   "CCT2"
# [13] "ENO1"     "PGAM1"    "PRDX1"    "PRMT1"    "TNFRSF18" "XCL2"
# [19] "CRTAM"    "PPA1"     "RAN"      "VDAC1"    "XCL1"     "CCT5"
# [25] "CCT6A"    "HSP90B1"  "NDUFAB1"  "NFKBIA"   "PARK7"    "BIRC3"
# [31] "DCTPP1"   "DNPH1"    "EIF3I"    "FBL"      "GTF3C6"   "HSP90AB1"
# [37] "ILF2"     "PHB"      "SEC11C"   "TIMM13"   "TXNDC17"  "CALR"
# [43] "DUT"      "TNIP2"    "BATF"     "LSM5"     "BANF1"    "IMPDH2"
# [49] "NOP16"    "SNRPD1"
#
# $`CD8_MP8 Chromatin`
#  [1] "NEAT1"        "SYNE2"        "MACF1"        "AHNAK"        "GOLGB1"
#  [6] "KMT2A"        "AKAP9"        "ANKRD11"      "NKTR"         "SMG1"
# [11] "SYNE1"        "ATRX"         "DDX17"        "GPRIN3"       "SMCHD1"
# [16] "UTRN"         "ZNF292"       "AKNA"         "ARGLU1"       "CHD2"
# [21] "ITGA4"        "PCSK7"        "PHF3"         "ROCK1"        "RORA"
# [26] "ATF7IP"       "ATM"          "BPTF"         "CBLB"         "DDX6"
# [31] "DYNC1H1"      "FYN"          "LINC-PINT"    "MT-ND6"       "MYH9"
# [36] "NUFIP2"       "OGA"          "PDE3B"        "RESF1"        "RP11-138A9.1"
# [41] "SETX"         "XIST"         "SLFN5"        "EML4"         "GCC2"
# [46] "IKZF3"        "BDP1"         "RASGRP1"      "GOLGA4"       "CEP350"
#
# $`CD8_MP9 Unassigned2`
#  [1] "COTL1"    "PPP1CA"   "PSME2"    "ARPC1B"   "FKBP1A"   "LGALS1"
#  [7] "CAP1"     "ENO1"     "MT2A"     "TPI1"     "TUBB"     "PARK7"
# [13] "S100A4"   "APOBEC3G" "ARPC5"    "CAPZB"    "CORO1A"   "EMP3"
# [19] "PKM"      "PPP1R18"  "ANXA5"    "ARPC4"    "ATP5G3"   "CALM3"
# [25] "CLIC1"    "GZMA"     "GZMH"     "LSP1"     "PGAM1"    "PSME1"
# [31] "S100A11"  "STMN1"    "TXN"      "ACTB"     "BLOC1S1"  "C12ORF75"
# [37] "CAPG"     "CKLF"     "IL32"     "MYL12A"   "PSMA7"    "RAC2"
# [43] "SLC25A5"  "SNRPE"    "TBC1D10C" "CD52"     "SH3BGRL3" "ITM2C"
# [49] "PFN1"     "LY6E"
#
# $`CD8_MP10 Heat_shock`
#  [1] "HSPA1B"   "HSPH1"    "HSPA1A"   "HSPA6"    "HSPB1"    "ZFAND2A"
#  [7] "CACYBP"   "HSPD1"    "AHSA1"    "DNAJA1"   "HSPE1"    "MRPL18"
# [13] "PPP1R15A" "SERPINH1" "TSPYL2"   "BAG3"     "DNAJB1"   "HSP90AA1"
# [19] "IFNG"     "DEDD2"    "FKBP4"    "HSP90AB1" "NEU1"     "RGS2"
# [25] "CHORDC1"  "DNAJA4"   "DOK2"     "GADD45B"  "NUDC"     "BATF"
# [31] "CLK1"     "NR4A1"    "NR4A2"    "PMAIP1"   "RHOB"     "SQSTM1"
# [37] "TAF7"     "TCP1"     "TNFSF14"  "JUN"      "DUSP1"    "CCL3"
# [43] "CCL4L2"   "STIP1"    "FOSB"     "DUSP4"    "HSPA4"    "ANKRD37"
# [49] "TXNIP"    "PTGES3"
#
# $`CD8_MP11 Naive3`
#  [1] "KLRB1"    "LTB"      "RORA"     "IL7R"     "NCR3"     "SPOCK2"
#  [7] "TMIGD2"   "CCR6"     "CTSH"     "FKBP11"   "CCL20"    "HPGD"
# [13] "IL4I1"    "LST1"     "ALOX5AP"  "AQP3"     "CEBPD"    "CXCR6"
# [19] "GNA15"    "GPR171"   "GPR65"    "JAML"     "ODF2L"    "PERP"
# [25] "RBMS1"    "TANK"     "TNFRSF25" "FURIN"    "IFI44"    "IFNGR1"
# [31] "LGALS3"   "PHACTR2"  "RBPJ"     "ANKRD28"  "NINJ1"    "ERN1"
# [37] "TNFSF13B" "NFKBIA"   "TTC39C"   "CELF2"    "HOPX"     "MAF"
# [43] "GNLY"     "SATB1"    "CERK"     "GPX1"     "PFKFB3"   "TNFRSF18"
# [49] "PRDM1"    "SNX9"
#
# $`CD8_MP12 Dysfunction`
#  [1] "TNFRSF18" "ARID5B"   "BATF"     "NR3C1"    "TIGIT"    "CXCL13"
#  [7] "PKM"      "TNFRSF4"  "UCP2"     "C9ORF16"  "CD27"     "DNPH1"
# [13] "BIRC3"    "CTLA4"    "LTB"      "PARK7"    "PMAIP1"   "TNFRSF9"
# [19] "CNIH1"    "DUSP4"    "GBP2"     "IL6ST"    "ITM2A"    "NFKBIA"
# [25] "PEBP1"    "PGAM1"    "SPOCK2"   "TBC1D4"   "CD82"     "CORO1B"
# [31] "GEM"      "ICA1"     "IL7R"     "KLRB1"    "MAF"      "MAGEH1"
# [37] "RBPJ"     "SNX9"     "STAT3"    "AP2M1"    "CCR7"     "CHN1"
# [43] "CRTAM"    "EIF3I"    "FKBP1A"   "FKBP5"    "GPX4"     "HSPB1"
# [49] "ICOS"     "IGFLR1"

# %% [markdown]
# ## Load counts matrix

# %%
seurat_object <- readRDS("../../../Data/PerDataset/Sparks2023/GSE206265_covid_flu.CITEseq.Seurat.obj.RDS")

# %%
cells_fn <- '../../../Data/PerDataset/Sparks2023/T_fromSeurat.FiltForcNMF.Cell_list.tsv'
hvg_fn <-  '../../../Data/PerDataset/Sparks2023/T_fromSeurat.RNA.HVGlist.tsv'
hvgs = read.table(hvg_fn) %>% as.list %>% unname %>% unlist
cells_ind = read.table(cells_fn) %>% as.list %>% unname %>% unlist

# %%
seurat_object

# %%
filt = subset(seurat_object, cells = cells_ind)

# %%
c

# %%
filt@assays

# %%
DefaultAssay(filt) <- "RNA"

# %%
filt

# %%
filt_norm <- NormalizeData(object = filt, normalization.method = 'RC', scale.factor = 1e6)

# %%
# rna = filt@assays$RNA@counts
# adt = filt@assays$CITE@counts
# hto = filt@assays$HTO@counts

# rna_adt_hto = rbind(rna, adt, hto)

# %% [markdown]
# ## Score using MPs

# %%
MP_list %>% str(1)

# %%
names(MP_list[['CD4_T_cells']]) = paste0('CD4_', names(MP_list[['CD4_T_cells']]))
names(MP_list[['CD8_T_cells']]) = paste0('CD8_', names(MP_list[['CD8_T_cells']]))

MP_list = c(MP_list[['CD4_T_cells']], MP_list[['CD8_T_cells']])

# %%
MP_list

# %%
for (l in MP_list){
    print(l  %>% length)
}

# %%
# #' @title Filter genes in sigs according to reference 
# #' @description Filter genes in sigs according to reference 
# #' @param sigs a character vector of genes or list of character vectors to filter 
# #' @param ref reference genes to filter sigs according to
# #' @param conserved the minimum allowed fraction of genes retained after filtering. Default: 0.7
# #' @return a filtered list of sigs. Returns NULL if no genes in any sigs are left. sigs with less than <conserved> fraction of genes retained will be removed. Returns input <sigs> if no genes are missing.
# #' @rdname filter_sigs
# #' @export 
# filter_sigs = function(sigs, ref, conserved = 0.7) {
#     # no need for filtering
#     if (all(unlist(sigs) %in% ref)) {
#         return(sigs)
#     }

#     # original n of sigs
#     ngr0 = length(sigs)
#     # original n of genes in sigs
#     nge0 = lengths(sigs)
    
#     # filter sigs according to ref
#     sigs = sapply(sigs, function(group) group[group %in% ref], simplify = F)
#     # new n of genes in sigs
#     nge1 = lengths(sigs)

#     # return NULL if NO genes left
#     if (all(nge1 == 0)) {
#         return(NULL)
#     }
    
#     # fractions of genes retained after filtering
#     frac.conserved = nge1/nge0

#     # filter sigs based on fractions
#     sigs = sigs[frac.conserved >= conserved]

#     # pretty fractions for printing
#     frac.conserved = round(frac.conserved, 2)
#     frac.conserved = paste(names(frac.conserved), frac.conserved, sep = ": ")

#     # new n of sigs
#     # after fraction filtering
#     ngr1 = length(sigs)
    
#     # stop if no sigs left
#     if (ngr1 == 0) {
#         stop('No sigs left to score with.')
#     }

#     # remove filtered-out sigs from n gene counts
#     # so that nge0 and nge1 have same (relevant) sigs
#     nge1 = nge1[names(ngr1)]
#     nge0 = nge0[names(ngr1)]

#     # warning if entire sigs were filtered out
#     if (ngr1 < ngr0) {
#         warning('Removed ', ngr0 - ngr1, ' out of ', ngr0,
#                 ' sigs with < ', conserved * 100,
#                 '% genes retained after filtering...')
#     }

#     # warning if some genes were filtered out from one or more sigs
#     if (any(nge1 != nge0)) {
#         warning('Some genes were filtered out. Fractions retained:','\n',
#                 paste0(frac.conserved, collapse = "\n"))
#     }

#     # return filtered sigs
#     sigs
# }

# #' @title Basic Scoring of Matrix by Gene sigs 
# #' @description Average expression level of each column in m for (each) sig(s) in <sigs>.
# #' @param m a non-centered matrix of genes X cells/samples. The matrix will be row-centered internally prior to scoring.
# #' @param sigs a character vector of genes or list of character vectors. Sigs will be filtered to remove genes that are missing from rows in <m>.
# #' @param conserved.genes minimum fraction of genes retained in sigs after filtering that is allowed. sigs not passing this cutoff will not be used to score the matrix. This can be ignored if all genes in sigs are present in rownames(<m>). Default: 0.7
# #' @return a dataframe of scores, with as many rows as there are columns in <m> and as many columns as there are <sigs> to score against.
# #' @rdname baseScores
# #' @export 
# baseScores = function(m, sigs, conserved.genes = 0.7) {
#     if (is.character(sigs)) sigs = list(sigs)
#     sigs = filter_sigs(sigs, ref = rownames(m), conserved = conserved.genes)
#     sapply(sigs, function(sig) colMeans(m[sig, , drop = F]))
# }


# #' @title Score a Matrix by Gene sigs (Signatures) 
# #' @description Score a Matrix by Gene sigs (Signatures). Raw scores are generated with scalop::baseScores (i.e. average expression level of genes in the signature in question). Options to normalise scores either by centering by the average expression level across all genes for each column of <m> (cells/samples) or by subtracting a score from an expression-bin-matched group. The default is the latter. 
# #' @param m a non-centered matrix of genes X cells/samples. The matrix will be row-centered internally prior to scoring.
# #' @param sigs a character vector of genes or list of character vectors. Sigs will be filtered to remove genes that are missing from rows in <m>.
# #' @param groups if scores should be calculated intra-tumour, a list of cell IDs by sample. Default: NULL
# #' @param conserved.genes minimum fraction of genes retained in sigs after filtering that is allowed. sigs not passing this cutoff will not be used to score the matrix. This can be ignored if all genes in sigs are present in rownames(<m>). Default: 0.7
# #' @param expr.center normalise scores by subtracting scores generated from expression-bin-matched sigs. Set to FALSE if not desired. If expr.center = T and center = T, expr.center takes precedence. Default: T
# #' @param center Only relevant if expr.center = FALSE. If TRUE, normalise the scores by subtracting  the mean expression level across all genes (i.e. centering). No scaling is performed. Set to FALSE i f not desired. If expr.center = T and center = T, expr.center takes precedence. Default: T
# #' @param expr.bin.m if provided, this matrix will be used to bin the genes and generated expression-bin-matched sigs. Only relevant if expr.center = T. If NULL, <m> will be used. Default: NULL
# #' @param expr.bins if provided, these bins will be used to generated bin-matched sigs. Useful if you would like to use the same bins across several scoring analyses, or if your bins control for something other than global gene expression levels. Should be a vector of bin IDs with gene names as vector names. If NULL, will be computed from expr.bin.m (see above). Only relevant if expr.center = T. Default: NULL
# #' @param expr.sigs if provided, a character vector or list of character vectors of the same length as <sigs>. Scores with expr.sigs will be subtracted from the real group scores. If NULL and expr.center = T, these will be defined internally as expression-bin-matched sigs to correct the scores. Default: NULL
# #' @param expr.nbin if expr.center = T and the expr.sigs are to be generated from scratch, the number of desired expression bins. For example, you should make expr.nbin smaller if you have fewer genes, as you would like a good number of bin-matched genes in each bin group. Default: 30
# #' @param expr.binsize the number of bin-matched genes to take per gene in each group. Default: 100
# #' @param replace if TRUE, the same bin-matched gene can be taken more than once for the control expr.group. Default: F
# #' @return a dataframe of cell/sample scores. Has the same number of rows as there are columns in <m> and the same number of columns as there are sigs to score (assumming no sigs are filtered out because of missing genes).
# #' @rdname sigScores
# #' @export 
# sigScores = function(m,
#                      sigs,
#                      groups = NULL,
#                      center.rows = TRUE,
#                      center = T,
#                      expr.center = T,
#                      expr.bin.m = NULL,
#                      expr.bins = NULL,
#                      expr.sigs = NULL,
#                      expr.nbin = 30,
#                      expr.binsize = 100,
#                      conserved.genes = 0.7,
#                      replace = F) {

#     # if only one group, convert to list
#     if (is.character(sigs)) sigs = list(sigs)

#     # filter sigs
#     sigs = filter_sigs(sigs, ref = rownames(m), conserved = conserved.genes)

#     Args = mget(ls())

#     if (!is.null(groups)) {
#         Args$expr.bin.m <- m
#         Args = Args[names(Args) != 'm']
#         mlist = sapply(groups, function(sample) m[, sample], simplify = F)
#         res = sapply(mlist, function(m) {
#                          do.call(.sigScores, c(list(m = m), Args))},
#                          simplify = F)

#         cells = unlist(sapply(res, rownames, simplify = F))
#         res = do.call(rbind.data.frame, res)
#         rownames(res) = cells
#     }

#     else res = do.call(.sigScores, Args)

#     res
# }


# .sigScores = function(m,
#                       sigs,
#                       groups = NULL,
#                       center.rows = TRUE,
#                       center = T,
#                       expr.center = T,
#                       expr.bin.m = NULL,
#                       expr.bins = NULL,
#                       expr.sigs = NULL,
#                       expr.nbin = 30,
#                       expr.binsize = 100,
#                       conserved.genes = 0.7,
#                       replace = F) {

#     # base scores (no centering / expression normalisation of scores (yet))
#     if (center.rows) {
#         scores = baseScores(m = rowcenter(m), sigs = sigs, conserved.genes = conserved.genes)
#     } else {
#         scores = baseScores(m = m, sigs = sigs, conserved.genes = conserved.genes)
#     }
#     # no mean centering OR expr/complexity centering
#     if (!center) expr.center = F

#     if (expr.center) {
#         if (is.null(expr.sigs)) {

#             if (is.null(expr.bins)) {
#                 if (is.null(expr.bin.m)) expr.bin.m = m
#                 expr.bins = bin(expr.bin.m, breaks = expr.nbin)
#                 stopifnot(all(unlist(sigs) %in% names(expr.bins)))
#             }

#             expr.sigs = sapply(sigs,
#                                binmatch,
#                                bins = expr.bins,
#                                n = expr.binsize,
#                                replace = replace,
#                                simplify = F)

#             names(expr.sigs) = names(sigs)
#         }

#         if (center.rows) {
#             expr.scores = baseScores(m = rowcenter(m), sigs = expr.sigs)
#         } else {
#             expr.scores = baseScores(m = m, sigs = expr.sigs)
#         }
#         scores = scores - expr.scores
#     }

#     else if (center) {
#         if (!is.null(expr.bin.m)) center.scores = colMeans(expr.bin.m)
#         else center.scores = colMeans(m)
#         scores2 = sweep(scores, MARGIN = 1, STATS = center.scores, FUN = "-")
#     }

#     rows = rownames(scores)
#     scores = as.data.frame(scores)
#     rownames(scores) = rows
#     scores
# }

# #' @title Score a Matrix with Marker Gene Sets Of Normal Cell Types 
# #' @description Score a Matrix with Marker Gene Sets Of Normal Cell Types. Wrapper around scalop::sigScores. Please see `?scalop::sigScores` for more details
# #' @param m a non-centered matrix of genes X cells/samples. The matrix will be row-centered internally prior to scoring.
# #' @param ... other arguments passed to scalop::sigScores, although none are required. 
# #' @details the gene sets can be seen in Markers_Normal
# #' @return a dataframe of cell/sample scores. Each column describes scores for a different Marker Gene Set.  
# #' @rdname markerScores
# #' @export 
# markerScores = function(m, ...) {
#     sigs = suppressWarnings(filter_sigs(Markers_Normal, ref = rownames(m), conserved = 0.4))
#     sigs = sigs[lengths(sigs) >= 2]
#     sigScores(m = m, sigs = sigs, conserved.genes = conserved, ...)
# }

# %%
X = GetAssayData(filt_norm)

# %%
X %>% dim

# %%
set.seed(123)

# %%
sample_ind = sample(colnames(X), 500)

# %%
X[0:5, 0:5]

# %%
X_test = X[, sample_ind]

# %%
X_test %>% dim

# %%
My_study[1] %>% head

# %%
My_study[[1]] %>% str

# %%
X_test %>% str

# %%
print('done')

# %%
as.matrix(My_study[[1]])

# %%
system.time({
    scores = sigScores(as.matrix(My_study[[1]]), sigs = MP_list,  conserved.genes = MinGenes/50 )
})

# %%
scores

# %%
system.time({
    scores = sigScores(X_test, sigs = MP_list,  conserved.genes = MinGenes/50 )
})

# %%
X_test %>% dim

# %%
scores

# %%
# MP_scores_per_sample    <- lapply(L, function(x)  scalop::sigScores(x, sigs = MP_list, conserved.genes = MinGenes/50 )  )

# %%
print('done?')

# %%
My_study$Puram_2017_HNSCC_scRNAseq_26[1:5, 1:5]

# %%
My_study %>% str

# %% [markdown]
# ```
# # -------------------------------------------------------------------------------------------
# # Program for depicting the MP distribution of a given cell types across and within samples
# # -------------------------------------------------------------------------------------------
#
# # My_study  = a list in which each element represents a sample in the study; the elements are expression matrices of a given cell type (i.e. cell_type below) in CPM or TPM units. Row names in each matrix should be gene symbols, and column names the cell IDs.
# # cell_type = one of the following cell types : "Cancer" , "Endothelial" , "Epithelial" , "Fibroblasts" , "Macrophages" , "CD4_T_cells", "CD8_T_cells" , "B_cells". Here "Cancer" represents malignant cells
# # MinGenes  = the min number of MP genes that should exist in the study (default is 25)
# # MinScore  = the minimal score for assigning a cell to a MP (default is 1). A cell is assigned to the MP with the maximal score, given that it exceeded MinScore. If the maximal score is below MinScore, the cell is unassigned.
# # MinCells  = the minimal % of cells that should be assigned to a MP in order to account for the MP (default is 0.05)
# # MP_list   = a list of the MPs for each cell_type
#
# ### Output:
# # (a) Pie chart of the MP distribution across the study
# # (b) Bar plot per tumor with the % of cells per MP
# # (c) Expression heatmap per tumor
#
#
#
# # -------------------------------------------------------------------------------------------
#
#
# library(ggplot2)
# library(scalop)  # see https://rdrr.io/github/jlaffy/scalop/man/sigScores.html
# library(gridExtra)
# library(ggpubr)
#
#
#
# ### Define the following:
# # My_study  =
# # cell_type =
# # MP_list   = readRDS("MP_list.RDS")   # can be found in the Github repository
# # heatCols  = readRDS("heatCols.RDS")  # can be found in the Github repository
#
#
# Score_cells <- function(L,
#                         cell_type,
#                         MinGenes = 25,
#                         MinScore = 1,
#                         MinCells = 0.05,
#                         MP_list
#                         )
#   {
#
#   MP_list <- MP_list[[cell_type]]
#
#   L <- lapply(L, function(x) log2((x/10) + 1) ) # Log normalize before scoring
#
#   MP_scores_per_sample    <- lapply(L, function(x)  scalop::sigScores(x, sigs = MP_list, conserved.genes = MinGenes/50 )  )
#
#   remove_cells <- function(x,MinScore){         # remove cells whose max score was below MinScore
#     max_score <- apply(x, 1, function(y) max(y))
#     cells_rm  <- which(max_score < MinScore)
#     if (length(cells_rm) > 0 ){
#       x <- x[-cells_rm , ]
#     }
#     return(x)
#   }
#   MP_scores_per_sample <- lapply(MP_scores_per_sample, function(x) remove_cells(x,MinScore))
#
#   Assign_MP_per_cell   <- lapply(MP_scores_per_sample, function(x) apply(x, 1, function(y) colnames(x)[which(y==max(y))] ) )
#
#   filter_cells <- function(x,MinCells){         # remove MP that were assassin to less than MinCells in each sample
#     MP_frequency <- as.numeric(ave(x, x, FUN = length))
#     MP_rm        <- which(MP_frequency/length(x) < MinCells)  # MPs to be removed
#     if (length(MP_rm)>0){
#       x <- x[-MP_rm]
#     }
#     return(x)
#   }
#   Assign_MP_per_cell_filtered <- lapply(Assign_MP_per_cell, function(x) filter_cells(x,MinCells))
#
#   return(Assign_MP_per_cell_filtered)
#
# }
#
#
# Assign_MP_per_cell_filtered <- Score_cells(L = My_study , cell_type = "Cancer" , MP_list=MP_list)
#
#
#
# #### Part A: pie chart of MPs across the whole study
# MinCells <- 0.05
# df       <- data.frame(MPs = names(table(unlist(Assign_MP_per_cell_filtered)))  ,  frequency = as.vector(table(unlist(Assign_MP_per_cell_filtered))) )
# MPs_rm   <- which(df$frequency/sum(df$frequency) < MinCells)  ## remove also MPs that were assassin to less than MinCells from the total
# if (length(MPs_rm > 0)){
#   df$MPs[MPs_rm] <- paste0("Other MPs (<", MinCells*100, "%)")
# }
#
#
# blank_theme <- theme_minimal()+
#   theme(
#     axis.title.x = element_blank(),
#     axis.title.y = element_blank(),
#     panel.border = element_blank(),
#     panel.grid=element_blank(),
#     axis.ticks = element_blank(),
#     plot.title=element_text(size=14, face="bold")
#   )
#
#
# pie <- ggplot(df, aes(x="", y=frequency, fill=MPs)) +
#        geom_bar(width = 1, stat = "identity") +
#        coord_polar("y", start=0)+
#        blank_theme +
#        theme(axis.text.x=element_blank())
#
#
# pie
#
#
# #### Part B: Bar plot with MP distribution per sample
#
# sample_num <- length(Assign_MP_per_cell_filtered)
# nCol       <- floor(sqrt(sample_num))
# MPs        <- unique(unlist(Assign_MP_per_cell_filtered))
#
# ### For arranging the full MP names as legend in the plot
# MP_list <- MP_list[[cell_type]]
# MPs     <- MPs[sort(match(MPs, names(MP_list)),index.return = T)$ix]
#
# Assign_MP_per_cell_filtered_abbrev <- lapply(Assign_MP_per_cell_filtered, function(x) apply(as.data.frame(x) , 1 , function(x)  strsplit(x, "[ ]")[[1]][1]) )
#
# df_list    <- lapply(Assign_MP_per_cell_filtered_abbrev, function(x) data.frame(MPs = names(table(x))  ,  frequency = as.vector(table(x))/sum(as.vector(table(x))) ))
# df_list2   <- lapply(Assign_MP_per_cell_filtered, function(x) data.frame(MPs = names(table(x))  ,  frequency = as.vector(table(x))/sum(as.vector(table(x))) ))
#
# P <- lapply(seq_along(df_list), function(I)
#      ggplot(data=df_list[[I]], aes(x=reorder(MPs,-frequency), y=frequency)) +
#      geom_bar(stat="identity")+
#      theme(axis.title.x=element_blank())+
#      ggtitle(names(df_list)[I])
#   )
#
#
# P
#
# #### Part C: an expression heatmap for each sample
#
# df_list_ordered  <- lapply(df_list, function(x) x[sort(x$frequency,decreasing = T , index.return = T)$ix,])  ## order MPs in each sample as in the bar plots, in decreasing order
# df_list_ordered2 <- lapply(df_list2, function(x) x[sort(x$frequency,decreasing = T , index.return = T)$ix,])  ## order MPs in each sample as in the bar plots, in decreasing order
#
#
# L1        <- lapply(seq_along(My_study), function(I) My_study[[I]][ , names(Assign_MP_per_cell_filtered[[I]])]) ## extract relevant cells that were assigned to an MP (at least 5%)
# names(L1) <- names(My_study)
#
# L1 <- lapply(L1, function(x) log2((x/10) + 1) ) ## Log normalize
# L1 <- lapply(L1, function(x) (x - rowMeans(x)) ) ## center
#
# L2 <- lapply(seq_along(L1), function(I) L1[[I]][ , sort(match(Assign_MP_per_cell_filtered_abbrev[[I]],df_list_ordered[[I]]$MPs), index.return = T)$ix] )  # sort cells according to MPs in df_list_ordered
# names(L2) <- names(L1)
#
# MP_genes_per_sample <- lapply(df_list_ordered2, function(x) unlist(MP_list[x$MPs]))  ### MP genes sorted by the MP order in df_list_ordered2
#
# L_plot        <- lapply(seq_along(L2), function(I) L2[[I]][match(MP_genes_per_sample[[I]] , rownames(L2[[I]]))[!is.na(match(MP_genes_per_sample[[I]] , rownames(L2[[I]])))] , ])
# names(L_plot) <- names(L2)
#
# color.scheme <- colorRampPalette(c(heatCols))(n=333)
#
# Plot_heatmap <- function(M){
#
#   M_new2        <- M
#   M_new2        <- apply(M_new2, 2, rev)
#   M_meltII      <-  reshape2::melt(t(M_new2))
#   M_meltII$Var2 <- factor(M_meltII$Var2)
#
#   G <- ggplot(data = M_meltII, aes(x=Var1, y=Var2, fill=value, color=value)) +
#     geom_tile() +
#     scale_color_gradient2(limits=c(-4,4), low=color.scheme[1:111],  mid =color.scheme[112:222], high = color.scheme[223:333], midpoint = 0, oob=squish, name=NULL) +
#     scale_fill_gradient2(limits=c(-4,4), low=color.scheme[1:111],  mid =color.scheme[112:222], high = color.scheme[223:333], midpoint = 0, oob=squish, name=NULL)  +
#     theme(  panel.border = element_rect(fill=F), panel.background = element_blank(),  axis.line = element_blank(), axis.text = element_text(size = 8), axis.title = element_text(size = 8), legend.title = element_text(size=8), legend.text = element_text(size = 8), legend.text.align = 0.5, legend.justification = "bottom" ) +
#     theme(axis.title.x=element_blank(), axis.text.x=element_blank(), axis.ticks.x=element_blank()) +
#     theme(axis.title.y=element_blank(), axis.text.y=element_blank(), axis.ticks.y=element_blank() )
#
#   return(G)
# }
#
# P1 <- lapply(L_plot, function(x) Plot_heatmap(x))
#
# P_plot <- c()
# for (i in 1:length(P)){
#   P_plot <- c(P_plot , P[i] , P1[i])
# }
#
#
# P_plot <- do.call("ggarrange", c(P_plot, ncol=2, nrow = 3))
#
# lapply(P_plot, function(x)
#
#   annotate_figure(x, left   = text_grob(paste(MPs , collapse = "\n"),
#                                         color = "red", face = "bold", size = 10))
#
# )
# ```
